# %% [markdown]
# # Dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as spstats
# %matplotlib inline

# %%
df_orders = pd.read_csv("olist_order_items_dataset.csv")

# %%
df_orders.head(4)
# Out:
#                                   order_item_id  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214              1
# 00018f77f2f0320c557190d7a144bdd3              1
# 000229ec398224ef6ca0657da4fc703e              1
# 00024acbcdf0a6daa1e931b038114c75              1
#
#                                                         product_id  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f
# 000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd
# 00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc
#
#                                                          seller_id  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214  48436dade18ac8b2bce089ec2a041202
# 00018f77f2f0320c557190d7a144bdd3  dd7ddc04e1b6c2c614352b383efe2d36
# 000229ec398224ef6ca0657da4fc703e  5b51032eddd242adc84c38acab88f23d
# 00024acbcdf0a6daa1e931b038114c75  9d7a1d34a5052409006425275ba1c2b4
#
# ...

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
# order_id               112650 non-null object
# order_item_id          112650 non-null int64
# product_id             112650 non-null object
# seller_id              112650 non-null object
# shipping_limit_date    112650 non-null object
# price                  112650 non-null float64
# freight_value          112650 non-null float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
df_orders.describe()#no missing values!!
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %%
df_orders['order_item_id'].value_counts()
# Out:
# 1     98666
# 2      9803
# 3      2287
# 4       965
# 5       460
# 6       256
# 7        58
# 8        36
# 9        28
# 10       25
# 11       17
# 12       13
# 13        8
# 14        7
# 15        5
# 20        3
# 16        3
# 17        3
# 18        3
# 19        3
# 21        1
# Name: order_item_id, dtype: int64

# %%
df_customers =pd.read_csv("olist_customers_dataset.csv")

# %%
df_customers.head(4)
# Out:
#                                                 customer_unique_id  \
# customer_id
# 06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
#
#                                   customer_zip_code_prefix  \
# customer_id
# 06b8999e2fba1a1fbc88172c00ba8bc7                     14409
# 18955e83d337fd6b2def6b18a428ac77                      9790
# 4e7b3e00288586ebd08712fdd0374a03                      1151
# b2b6027bc5c5109e529d4dc6358b12c3                      8775
#
#                                           customer_city customer_state
# customer_id
# 06b8999e2fba1a1fbc88172c00ba8bc7                 franca             SP
# 18955e83d337fd6b2def6b18a428ac77  sao bernardo do campo             SP
# 4e7b3e00288586ebd08712fdd0374a03              sao paulo             SP
# ...

# %%
df_customers.info() #no missing data here as well. 
#Only one num col of zipcode.Useless.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
# customer_id                 99441 non-null object
# customer_unique_id          99441 non-null object
# customer_zip_code_prefix    99441 non-null int64
# customer_city               99441 non-null object
# customer_state              99441 non-null object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
df_purchase = pd.read_csv("olist_orders_dataset.csv")

# %%
df_purchase.head(4)
# Out:
#                                                        customer_id  \
# order_id
# e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
#
#                                  order_status order_purchase_timestamp  \
# order_id
# e481f51cbdc54678b7cc49136f2d6af7    delivered      2017-10-02 10:56:33
# 53cdb2fc8bc7dce0b6741e2150273451    delivered      2018-07-24 20:41:37
# 47770eb9100c2d0c44946d9cf07ec65d    delivered      2018-08-08 08:38:49
# 949d5b44dbf5de918fe9c16f97b45f8a    delivered      2017-11-18 19:28:06
#
#                                     order_approved_at  \
# order_id
# e481f51cbdc54678b7cc49136f2d6af7  2017-10-02 11:07:15
# 53cdb2fc8bc7dce0b6741e2150273451  2018-07-26 03:24:27
# 47770eb9100c2d0c44946d9cf07ec65d  2018-08-08 08:55:23
# ...

# %%
df_purchase.info()#missing data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
# order_id                         99441 non-null object
# customer_id                      99441 non-null object
# order_status                     99441 non-null object
# order_purchase_timestamp         99441 non-null object
# order_approved_at                99281 non-null object
# order_delivered_carrier_date     97658 non-null object
# order_delivered_customer_date    96476 non-null object
# order_estimated_delivery_date    99441 non-null object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
df_products= pd.read_csv('olist_products_dataset.csv')

# %%
df_products.head(4)
# Out:
#                          product_id product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5            perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                 artes
# 2  96bd76ec8810374ed1b65e291975717f         esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                 bebes
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# ...

# %%
df_products.info() #some missing data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
# product_id                    32951 non-null object
# product_category_name         32341 non-null object
# product_name_lenght           32341 non-null float64
# product_description_lenght    32341 non-null float64
# product_photos_qty            32341 non-null float64
# product_weight_g              32949 non-null float64
# product_length_cm             32949 non-null float64
# product_height_cm             32949 non-null float64
# product_width_cm              32949 non-null float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
df_products.describe()
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %%
df_sellers= pd.read_csv('olist_sellers_dataset.csv')

# %%
df_sellers.head(4)
# Out:
#                                   seller_zip_code_prefix     seller_city  \
# seller_id
# 3442f8959a84dea7ee197c632cb2df15                   13023        campinas
# d1b65fc7debc3361ea86b5f14c68d2e2                   13844      mogi guacu
# ce3ad9de960102d0677a81f5d0bb7b2d                   20031  rio de janeiro
# c0f3eea2e14555b6faeea3dd58c1b1c3                    4195       sao paulo
#
#                                  seller_state
# seller_id
# 3442f8959a84dea7ee197c632cb2df15           SP
# d1b65fc7debc3361ea86b5f14c68d2e2           SP
# ce3ad9de960102d0677a81f5d0bb7b2d           RJ
# c0f3eea2e14555b6faeea3dd58c1b1c3           SP

# %%
df_sellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
# seller_id                 3095 non-null object
# seller_zip_code_prefix    3095 non-null int64
# seller_city               3095 non-null object
# seller_state              3095 non-null object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
df_sellers.describe()
# Out:
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %%
df_payment =pd.read_csv('olist_order_payments_dataset.csv')

# %%
df_payment.head(4)
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78

# %%
df_payment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
# order_id                103886 non-null object
# payment_sequential      103886 non-null int64
# payment_type            103886 non-null object
# payment_installments    103886 non-null int64
# payment_value           103886 non-null float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
df_payment.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %%
df_geoloc =pd.read_csv('olist_geolocation_dataset.csv')

# %%
df_geoloc.head(4)
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP

# %%
df_geoloc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
# geolocation_zip_code_prefix    1000163 non-null int64
# geolocation_lat                1000163 non-null float64
# geolocation_lng                1000163 non-null float64
# geolocation_city               1000163 non-null object
# geolocation_state              1000163 non-null object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
df_geoloc.describe()
# Out:
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                 1.000163e+06     1.000163e+06     1.000163e+06
# mean                  3.657417e+04    -2.117615e+01    -4.639054e+01
# std                   3.054934e+04     5.715866e+00     4.269748e+00
# min                   1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                   1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                   2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                   6.350400e+04    -1.997962e+01    -4.376771e+01
# max                   9.999000e+04     4.506593e+01     1.211054e+02

# %%
df_reviews = pd.read_csv('olist_order_reviews_dataset.csv')

# %%
df_reviews.head(4)
# Out:
#                                                          review_id  \
# order_id
# 73fc7af87114b39712e6da79b0a377eb  7bc2406110b926393aa56f80a40eba40
# a548910a1c6147796b98fdf73dbeba33  80e641a11e56f04c1ad469d5645fdfde
# f9e4b658b201a9f2ecdecbb34bed034b  228ce5500dc1d8e020d8d1322874b6f0
# 658677c97b385a9be170737859d3511b  e64fb393e7b32834bb789ff8bb30750e
#
#                                   review_score review_comment_title  \
# order_id
# 73fc7af87114b39712e6da79b0a377eb             4                  NaN
# a548910a1c6147796b98fdf73dbeba33             5                  NaN
# f9e4b658b201a9f2ecdecbb34bed034b             5                  NaN
# 658677c97b385a9be170737859d3511b             5                  NaN
#
#                                                  review_comment_message  \
# order_id
# 73fc7af87114b39712e6da79b0a377eb                                    NaN
# a548910a1c6147796b98fdf73dbeba33                                    NaN
# ...

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
# review_id                  100000 non-null object
# order_id                   100000 non-null object
# review_score               100000 non-null int64
# review_comment_title       11715 non-null object
# review_comment_message     41753 non-null object
# review_creation_date       100000 non-null object
# review_answer_timestamp    100000 non-null object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
df_reviews.describe()
# Out:
#         review_score
# count  100000.000000
# mean        4.070890
# std         1.359663
# min         1.000000
# 25%         4.000000
# 50%         5.000000
# 75%         5.000000
# max         5.000000

# %%
df_reviews.set_index('order_id',inplace=True)

# %%
df_orders.set_index('order_id',inplace=True)

# %%
df_orders
# Out:
#                                   order_item_id  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214              1
# 00018f77f2f0320c557190d7a144bdd3              1
# 000229ec398224ef6ca0657da4fc703e              1
# 00024acbcdf0a6daa1e931b038114c75              1
# 00042b26cf59d7ce69dfabb4e55b4fd9              1
# 00048cc3ae777c65dbb7d2a0634bc1ea              1
# 00054e8431b9d7675808bcb819fb4a32              1
# 000576fe39319847cbb9d288c5617fa6              1
# 0005a1a1728c9d785b8e2b08b904576c              1
# 0005f50442cb953dcd1d21e1fb923495              1
# 00061f2a7bc09da83e415a52dc8a4af1              1
# 00063b381e2406b52ad429470734ebd5              1
# 0006ec9db01a64e59a68b2c340bf65a7              1
# 0008288aa423d2a3f00fcb17cd7d8719              1
# 0008288aa423d2a3f00fcb17cd7d8719              2
# 0009792311464db532ff765bf7b182ae              1
# 0009c9a17f916a706d71784483a5d643              1
# 000aed2e25dbad2f9ddb70584c5a2ded              1
# ...

# %%
df_orders_reviews=df_orders.merge(df_reviews,how='inner', on='order_id',indicator=True)

# %%
df_orders_reviews
# Out:
#                                   order_item_id  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214              1
# 00018f77f2f0320c557190d7a144bdd3              1
# 000229ec398224ef6ca0657da4fc703e              1
# 00024acbcdf0a6daa1e931b038114c75              1
# 00042b26cf59d7ce69dfabb4e55b4fd9              1
# 00048cc3ae777c65dbb7d2a0634bc1ea              1
# 00054e8431b9d7675808bcb819fb4a32              1
# 000576fe39319847cbb9d288c5617fa6              1
# 0005a1a1728c9d785b8e2b08b904576c              1
# 0005f50442cb953dcd1d21e1fb923495              1
# 00061f2a7bc09da83e415a52dc8a4af1              1
# 00063b381e2406b52ad429470734ebd5              1
# 0006ec9db01a64e59a68b2c340bf65a7              1
# 0008288aa423d2a3f00fcb17cd7d8719              1
# 0008288aa423d2a3f00fcb17cd7d8719              2
# 0009792311464db532ff765bf7b182ae              1
# 0009c9a17f916a706d71784483a5d643              1
# 000aed2e25dbad2f9ddb70584c5a2ded              1
# ...

# %%
df_orders_with_reviews['merge_orders_reviews']=df_orders_with_reviews._merge

# %%
df_orders_with_reviews.drop('_merge',axis=1,inplace=True)

# %%
df_purchase.set_index('order_id',inplace=True)

# %%
df_orders_reviews_purchase=df_orders_with_reviews.merge(df_purchase,how='inner', on='order_id',indicator=True)

# %%
df_orders_reviews_purchase
# Out:
#                                   order_item_id  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214              1
# 00018f77f2f0320c557190d7a144bdd3              1
# 000229ec398224ef6ca0657da4fc703e              1
# 00024acbcdf0a6daa1e931b038114c75              1
# 00042b26cf59d7ce69dfabb4e55b4fd9              1
# 00048cc3ae777c65dbb7d2a0634bc1ea              1
# 00054e8431b9d7675808bcb819fb4a32              1
# 000576fe39319847cbb9d288c5617fa6              1
# 0005a1a1728c9d785b8e2b08b904576c              1
# 0005f50442cb953dcd1d21e1fb923495              1
# 00061f2a7bc09da83e415a52dc8a4af1              1
# 00063b381e2406b52ad429470734ebd5              1
# 0006ec9db01a64e59a68b2c340bf65a7              1
# 0008288aa423d2a3f00fcb17cd7d8719              1
# 0008288aa423d2a3f00fcb17cd7d8719              2
# 0009792311464db532ff765bf7b182ae              1
# 0009c9a17f916a706d71784483a5d643              1
# 000aed2e25dbad2f9ddb70584c5a2ded              1
# ...

# %%
df_payment
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# 5       298fcdf1f73eb413e4d26d01b25bc1cd                   1  credit_card
# 6       771ee386b001f06208a7419e4fc1bbd7                   1  credit_card
# 7       3d7239c394a212faae122962df514ac7                   1  credit_card
# 8       1f78449c87a54faf9e96e88ba1491fa9                   1  credit_card
# 9       0573b5e23cbd798006520e1d5b4c6714                   1       boleto
# 10      d88e0d5fa41661ce03cf6cf336527646                   1  credit_card
# 11      2480f727e869fdeb397244a21b721b67                   1  credit_card
# ...

# %%
df_orders_reviews_purchase_payment=df_orders_reviews_purchase.merge(df_payment,how='inner', on='order_id')

# %%
df_orders_reviews_purchase_payment
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# 5       00048cc3ae777c65dbb7d2a0634bc1ea              1
# 6       00054e8431b9d7675808bcb819fb4a32              1
# 7       000576fe39319847cbb9d288c5617fa6              1
# 8       0005a1a1728c9d785b8e2b08b904576c              1
# 9       0005f50442cb953dcd1d21e1fb923495              1
# 10      00061f2a7bc09da83e415a52dc8a4af1              1
# 11      00063b381e2406b52ad429470734ebd5              1
# 12      0006ec9db01a64e59a68b2c340bf65a7              1
# 13      0008288aa423d2a3f00fcb17cd7d8719              1
# 14      0008288aa423d2a3f00fcb17cd7d8719              2
# 15      0009792311464db532ff765bf7b182ae              1
# ...

# %%
df_sellers.set_index('seller_id', inplace=True)
df_sellers
# Out:
#                                   seller_zip_code_prefix  \
# seller_id
# 3442f8959a84dea7ee197c632cb2df15                   13023
# d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 51a04a8a6bdcb23deccc82b0b80742cf                   12914
# c240c4061717ac1806ae6ee72be3533b                   20920
# e49c26c3edfa46d227d5121a6b6e4d37                   55325
# 1b938a7ec6ac5061a66a3766e0e75f90                   16304
# 768a86e36ad6aae3d03ee3c6433d61df                    1529
# ccc4bbb5f32a6ab2b7066a4130f114e3                   80310
# 8cb7c5ddf41f4d506eba76e9a4702a25                   75110
# a7a9b880c49781da66651ccf4ba9ac38                   13530
# 8bd0f31cf0a614c658f6763bd02dea69                    1222
# 05a48cc8859962767935ab9087417fbb                    5372
# 7b8e8ec35bad4b0ef7e3963650b0a87b                   88705
# ...

# %%
df_orders_reviews_purchase_payment.set_index('seller_id',inplace=True)
df_orders_reviews_purchase_payment
# Out:
#                                                           order_id  \
# seller_id
# 48436dade18ac8b2bce089ec2a041202  00010242fe8c5a6d1ba2dd792cb16214
# dd7ddc04e1b6c2c614352b383efe2d36  00018f77f2f0320c557190d7a144bdd3
# 5b51032eddd242adc84c38acab88f23d  000229ec398224ef6ca0657da4fc703e
# 9d7a1d34a5052409006425275ba1c2b4  00024acbcdf0a6daa1e931b038114c75
# df560393f3a51e74553ab94004ba5c87  00042b26cf59d7ce69dfabb4e55b4fd9
# 6426d21aca402a131fc0a5d0960a3c90  00048cc3ae777c65dbb7d2a0634bc1ea
# 7040e82f899a04d1b434b795a43b4617  00054e8431b9d7675808bcb819fb4a32
# 5996cddab893a4652a15592fb58ab8db  000576fe39319847cbb9d288c5617fa6
# a416b6a846a11724393025641d4edd5e  0005a1a1728c9d785b8e2b08b904576c
# ba143b05f0110f0dc71ad71b4466ce92  0005f50442cb953dcd1d21e1fb923495
# cc419e0650a3c5ba77189a1882b7556a  00061f2a7bc09da83e415a52dc8a4af1
# 8602a61d680a10a82cceeeda0d99ea3d  00063b381e2406b52ad429470734ebd5
# 4a3ca9315b744ce9f8e9374361493884  0006ec9db01a64e59a68b2c340bf65a7
# ...

# %%
df_orders_reviews_purchase_payment_sellers=df_orders_reviews_purchase_payment.merge(df_payment,how='inner', on='seller_id')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-129-31108d31b9bf> in <module>
# ----> 1 df_orders_reviews_purchase_payment_sellers=df_orders_reviews_purchase_payment.merge(df_payment,how='inner', on='seller_id')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    6866                      right_on=right_on, left_index=left_index,
#    6867                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 6868                      copy=copy, indicator=indicator, validate=validate)
#    6869
#    6870     def round(self, decimals=0, *args, **kwargs):
#
# ...

# %%
df_customers
# Out:
#                                                 customer_unique_id  \
# customer_id
# 06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# 879864dab9bc3047522c92c82e1212b8  4c93744516667ad3b8f1fb645a3116a4
# fd826e7cf63160e536e0908c76c3f441  addec96d2e059c80c30fe6871d30d177
# 5e274e7a0c3809e14aba7ad5aae0d407  57b2a98a409812fe9618067b6b8ebe4f
# 5adf08e34b2e993982a47070956c5c65  1175e95fb47ddff9de6b2b06188f7e0d
# 4b7139f34592b3a31687243a302fa75b  9afe194fb833f79e300e37e580171f22
# 9fb35e4ed6f0a14a4977cd9aea4042bb  2a7745e1ed516b289ed9b29c7d0539a5
# 5aa9e4fdd4dfd20959cad2d772509598  2a46fb94aef5cbeeb850418118cee090
# b2d1536598b73a9abd18e0d75d92f0a3  918dc87cd72cd9f6ed4bd442ed785235
# ...

# %%
df_orders_reviews_purchase_payment.reset_index(inplace=True)

# %%
df_products
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# 5      41d3672d4792049fa1779bb35283ed13              instrumentos_musicais
# 6      732bd381ad09e530fe0a5f457d81becb                         cool_stuff
# 7      2548af3e6e77a690cf3eb6368e9ab61e                   moveis_decoracao
# 8      37cc742be07708b53a98702e77a21a02                   eletrodomesticos
# 9      8c92109888e8cdf9d66dc7e463025574                         brinquedos
# 10     14aa47b7fe5c25522b47b4b29c98dcb9                    cama_mesa_banho
# ...

# %%
df_orders_reviews_purchase_payment_products=df_orders_reviews_purchase_payment.merge(df_products,how='inner', on='product_id')

# %%
df_orders_reviews_purchase_payment_products
# Out:
#                                seller_id                          order_id  \
# 0       48436dade18ac8b2bce089ec2a041202  00010242fe8c5a6d1ba2dd792cb16214
# 1       48436dade18ac8b2bce089ec2a041202  130898c0987d1801452a8ed92a670612
# 2       48436dade18ac8b2bce089ec2a041202  532ed5e14e24ae1f0d735b91524b98b9
# 3       48436dade18ac8b2bce089ec2a041202  6f8c31653edb8c83e1a739408b5ff750
# 4       48436dade18ac8b2bce089ec2a041202  7d19f4ef4d04461989632411b7e588b9
# 5       48436dade18ac8b2bce089ec2a041202  a0f9acf0b6294ed8561e32cde1a966bc
# 6       48436dade18ac8b2bce089ec2a041202  bbf796534aaf9c59f8da8c7982db56e0
# 7       48436dade18ac8b2bce089ec2a041202  c9ef97d2854afe64a3b4488bc2836af6
# 8       48436dade18ac8b2bce089ec2a041202  df2d910b8b5e5f461f67043489f9569d
# 9       48436dade18ac8b2bce089ec2a041202  df2d910b8b5e5f461f67043489f9569d
# 10      48436dade18ac8b2bce089ec2a041202  df2d910b8b5e5f461f67043489f9569d
# ...

# %%
df_orders_reviews_purchase_payment_products_customers=df_orders_reviews_purchase_payment_products.merge(df_products,how='inner', on='customer_id')

# %%
df_geoloc
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# 5                               1012       -23.547762       -46.635361
# 6                               1047       -23.546273       -46.641225
# 7                               1013       -23.546923       -46.634264
# 8                               1029       -23.543769       -46.634278
# 9                               1011       -23.547640       -46.636032
# 10                              1013       -23.547325       -46.634184
# 11                              1032       -23.538418       -46.634778
# ...

# %% [markdown]
# # To The End:

# %% [markdown]
# ## Data Understanding and Preparations.

# %% [markdown]
# In this phase of the project, we import all the  data available to exctract useful insights and begin technical aspect of it.
#
# Source contains 8 partial datasets for complete analysis.
