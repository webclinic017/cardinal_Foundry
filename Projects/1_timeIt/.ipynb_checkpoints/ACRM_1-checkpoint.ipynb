# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 1000)

# %%
df= pd.read_csv('ACRM.csv')

# %%
df.head(4)
# Out:
#                            order_id                        product_id                         seller_id                       customer_id  order_item_id                customer_unique_id  shipping_limit_date order_purchase_timestamp    order_approved_at order_delivered_carrier_date order_delivered_customer_date order_estimated_delivery_date review_creation_date review_answer_timestamp  price  freight_value  customer_zip_code_prefix          customer_city customer_state  seller_zip_code_prefix    seller_city seller_state order_status  payment_sequential payment_type  payment_installments  payment_value                         review_id  review_score review_comment_title                             review_comment_message product_category_name  product_name_lenght  product_description_lenght  product_photos_qty  product_weight_g  product_length_cm  product_height_cm  product_width_cm
# ...

# %%
s1 = df.groupby('seller_state')['seller_id'].nunique().sort_values(ascending=False)
s1
# Out:
# seller_state
# SP    1849
# PR     349
# MG     244
# SC     190
# RJ     171
# RS     129
# GO      40
# DF      30
# ES      23
# BA      19
# CE      13
# PE       9
# PB       6
# MS       5
# RN       5
# MT       4
# SE       2
# RO       2
# AM       1
# PA       1
# MA       1
# PI       1
# AC       1
# Name: seller_id, dtype: int64

# %%
s1.plot(kind='pie',figsize=(15,8))

# %%
df.seller_city.value_counts()
# Out:
# sao paulo                                   29294
# ibitinga                                     8375
# curitiba                                     3158
# santo andre                                  3149
# sao jose do rio preto                        2693
# belo horizonte                               2688
# rio de janeiro                               2535
# guarulhos                                    2456
# ribeirao preto                               2374
# maringa                                      2293
# piracicaba                                   2036
# itaquaquecetuba                              1761
# campinas                                     1459
# salto                                        1400
# praia grande                                 1385
# campo limpo paulista                         1255
# guariba                                      1186
# sao bernardo do campo                        1185
# jacarei                                      1011
# ...

# %%
df_sellers=pd.read_csv('olist_sellers_dataset.csv')

# %%
df.groupby('customer_state')['customer_city'].nunique().sort_values
# Out:
# <bound method Series.sort_values of customer_state
# AC      8
# AL     68
# AM      5
# AP      6
# BA    352
# CE    161
# DF      6
# ES     95
# GO    177
# MA    121
# MG    744
# MS     67
# MT    101
# PA     89
# PB     92
# PE    152
# PI     72
# PR    363
# RJ    148
# RN     90
# RO     35
# RR      2
# RS    377
# SC    239
# SE     46
# SP    628
# TO     56
# Name: customer_city, dtype: int64>

# %%
df_sellers.seller_city.nunique()
# Out:
# 611

# %%
df_sellers.seller_id.nunique()
# Out:
# 3095

# %%
df_customers=pd.read_csv('olist_customers_dataset.csv')

# %%
df_orders=pd.read_csv('olist_order_items_dataset.csv')

# %%
df_orders
# Out:
#                                 order_id  order_item_id                        product_id                         seller_id  shipping_limit_date   price  freight_value
# 0       00010242fe8c5a6d1ba2dd792cb16214              1  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202  2017-09-19 09:45:35   58.90          13.29
# 1       00018f77f2f0320c557190d7a144bdd3              1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36  2017-05-03 11:05:13  239.90          19.93
# 2       000229ec398224ef6ca0657da4fc703e              1  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d  2018-01-18 14:48:30  199.00          17.87
# 3       00024acbcdf0a6daa1e931b038114c75              1  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
df.drop_duplicates(subset=['order_id'],keep='last',inplace=True)

# %%
df_orders.order_item_id.value_counts()
# Out:
# 1     98666
# 2      9803
# 3      2287
# 4       965
# 5       460
# 6       256
# 7        58
# 8        36
# 9        28
# 10       25
# 11       17
# 12       13
# 13        8
# 14        7
# 15        5
# 20        3
# 16        3
# 17        3
# 18        3
# 19        3
# 21        1
# Name: order_item_id, dtype: int64

# %%
df.groupby('order_item_id')['order_id'].nunique().sort_values(ascending=False).plot(kind='line')
plt.xlabel('items per order')
plt.ylabel('orders')
# Out:
# Text(0, 0.5, 'orders')

# %%
df_orders.seller_id.value_counts()
# Out:
# 6560211a19b47992c3666cc44a7e94c0    2033
# 4a3ca9315b744ce9f8e9374361493884    1987
# 1f50f920176fa81dab994f9023523100    1931
# cc419e0650a3c5ba77189a1882b7556a    1775
# da8622b14eb17ae2831f4ac5b9dab84a    1551
# 955fee9216a65b617aa5c0531780ce60    1499
# 1025f0e2d44d7041d6cf58b6550e0bfa    1428
# 7c67e1448b00f6e969d365cea6b010ab    1364
# ea8482cd71df3c1969d7b9473ff13abc    1203
# 7a67c85e85bb2ce8582c35f2203ad736    1171
# 4869f7a5dfa277a7dca6462dcf3b52b2    1156
# 3d871de0142ce09b7081e2b9d1733cb1    1147
# 8b321bb669392f5163d04c59e235e066    1018
# cca3071e3e9bb7d12640c9fbe2301306     830
# 620c87c171fb2a6dd6e8bb4dec959fc6     798
# a1043bafd471dff536d0c462352beb48     770
# e9779976487b77c6d4ac45f75ec7afe9     750
# f8db351d8c4c4c22c6835c19a46f01b0     724
# d2374cbcbb3ca4ab1086534108cc3ab7     631
# 391fc6631aebcf3004804e51b40bcf1e     613
# fa1c13f2614d7b5c4749cbc52fecda94     586
# 7d13fca15225358621be4086e1eb0964     578
# 128639473a139ac0f3e5f5ade55873a5     560
# ...

# %%
df.drop_duplicates(subset=['order_id'],keep='last',inplace=True)

# %%
df_orders.order_id.duplicated().any()
# Out:
# True

# %%
df_orders.size
# Out:
# 788550

# %%
df_orders.shape
# Out:
# (112650, 7)

# %%
((df.product_id.value_counts()) > 100).sum()
# Out:
# 48

# %%
df.product_id.nunique()
# Out:
# 32126

# %%
df.groupby('order_id')['price','freight_value'].sum().sum().round(2).plot('bar',cmap='inferno')

# %%
df.groupby('order_id')['price','freight_value'].sum().sum().round(2).to_frame()
# Out:
#                          0
# price          12430669.70
# freight_value   1991797.63

# %%
df_customers.customer_unique_id.value_counts()
# Out:
# 8d50f5eadf50201ccdcedfb9e2ac8455    17
# 3e43e6105506432c953e165fb2acf44c     9
# ca77025e7201e3b30c44b472ff346268     7
# 1b6c7548a2a1f9037c1fd3ddfed95f33     7
# 6469f99c1f9dfae7733b25662e7f1782     7
# 12f5d6e1cbf93dafd9dcc19095df0b3d     6
# 63cfc61cee11cbe306bff5857d00bfe4     6
# 47c1a3033b8b77b3ab6e109eb4d5fdf3     6
# f0e310a6839dce9de1638e0fe5ab282a     6
# dc813062e0fc23409cd255f7f53c7074     6
# de34b16117594161a6a89c50b289d35a     6
# 4e65032f1f574189fb793bac5a867bbc     5
# b4e4f24de1e8725b74e4a1f4975116ed     5
# fe81bb32c243a86b2f86fbf053fe6140     5
# 74cb1ad7e6d5674325c1f99b5ea30d82     5
# 394ac4de8f3acb14253c177f0e15bc58     5
# 5e8f38a9a1c023f3db718edcf926a2db     5
# 35ecdf6858edc6427223b64804cf028e     5
# 56c8638e7c058b98aae6d74d2dd6ea23     5
# 12d8b5ed661190a3a08183644dfc504d     4
# 7305430719d715992b00be82af4a6aa8     4
# 9cc5a07f169a1606fd347a56683e6ea6     4
# 4facc2e6fbc2bffab2fea92d2b4aa7e4     4
# 397b44d5bb99eabf54ea9c2b41ebb905     4
# ...

# %%
df.groupby('customer_state')['customer_unique_id'].nunique().sort_values(ascending=False).plot(kind='pie',)

# %%
df.shape
# Out:
# (98665, 39)

# %%
df.customer_city.nunique()
# Out:
# 4110

# %%
df.groupby('product_category_name')['product_id'].nunique().sort_values(ascending=False)
# Out:
# product_category_name
# cama_mesa_banho                                   2868
# esporte_lazer                                     2812
# moveis_decoracao                                  2523
# beleza_saude                                      2400
# utilidades_domesticas                             2276
# automotivo                                        1872
# informatica_acessorios                            1606
# brinquedos                                        1390
# relogios_presentes                                1321
# telefonia                                         1124
# bebes                                              903
# perfumaria                                         852
# papelaria                                          828
# fashion_bolsas_e_acessorios                        794
# cool_stuff                                         785
# ferramentas_jardim                                 735
# pet_shop                                           701
# ...

# %%
df_english_please = pd.read_csv('Other_product_category_name_translation.csv')

# %%
df_english_please
# Out:
#                              product_category_name            product_category_name_english
# 0                                     beleza_saude                            health_beauty
# 1                           informatica_acessorios                    computers_accessories
# 2                                       automotivo                                     auto
# 3                                  cama_mesa_banho                           bed_bath_table
# 4                                 moveis_decoracao                          furniture_decor
# 5                                    esporte_lazer                           sports_leisure
# 6                                       perfumaria                                perfumery
# 7                            utilidades_domesticas                               housewares
# 8                                        telefonia                                telephony
# ...

# %%
df_english_please.loc[df_english_please['product_category_name'].str.contains('cama_mesa_banho')]
# Out:
#   product_category_name product_category_name_english
# 3       cama_mesa_banho                bed_bath_table

# %%
df.groupby(['product_category_name','product_photos_qty'])['order_id'].nunique().sort_values(ascending=False)
# Out:
# product_category_name                          product_photos_qty
# cama_mesa_banho                                1.0                   6790
# beleza_saude                                   1.0                   5625
# esporte_lazer                                  1.0                   4189
# informatica_acessorios                         1.0                   3876
# moveis_decoracao                               1.0                   2741
# utilidades_domesticas                          1.0                   2650
# cool_stuff                                     1.0                   1952
# perfumaria                                     1.0                   1933
# relogios_presentes                             1.0                   1816
# ferramentas_jardim                             2.0                   1790
# eletronicos                                    1.0                   1747
# automotivo                                     1.0                   1562
# ...

# %%
df.groupby('product_category_name')['product_id'].nunique().sort_values(ascending=False)
# Out:
# product_category_name
# cama_mesa_banho                                   2868
# esporte_lazer                                     2812
# moveis_decoracao                                  2523
# beleza_saude                                      2400
# utilidades_domesticas                             2276
# automotivo                                        1872
# informatica_acessorios                            1606
# brinquedos                                        1390
# relogios_presentes                                1321
# telefonia                                         1124
# bebes                                              903
# perfumaria                                         852
# papelaria                                          828
# fashion_bolsas_e_acessorios                        794
# cool_stuff                                         785
# ferramentas_jardim                                 735
# pet_shop                                           701
# ...

# %%
df.groupby('review_score').order_id.count().plot('bar')

# %%
df.groupby(['payment_installments','payment_type'])['order_id'].count().sort_values(ascending=False).to_frame()
# Out:
#                                    order_id
# payment_installments payment_type
# 1                    credit_card      24303
#                      boleto           19614
# 2                    credit_card      12185
# 3                    credit_card      10287
# 4                    credit_card       6975
# 10                   credit_card       5211
# 5                    credit_card       5139
# 8                    credit_card       4214
# 6                    credit_card       3855
# 1                    voucher           2799
# 7                    credit_card       1602
# 1                    debit_card        1521
# 9                    credit_card        630
# 12                   credit_card        128
# 15                   credit_card         73
# 18                   credit_card         26
# 11                   credit_card         22
# 20                   credit_card         17
# 24                   credit_card         16
# ...

# %%
df.groupby('order_status')['order_id'].nunique().sort_values(ascending=False).to_frame()
# Out:
#               order_id
# order_status
# delivered        96477
# shipped           1106
# canceled           461
# invoiced           312
# processing         301
# unavailable          6
# approved             2

# %%
df['order_purchase_timestamp']=pd.to_datetime(df['order_purchase_timestamp'])
df['order_delivered_customer_date']=pd.to_datetime(df['order_delivered_customer_date'])

# %%
df['weekday']=df['order_purchase_timestamp'].dt.weekday_name
df['year']=df['order_purchase_timestamp'].dt.year
df['day']=df['order_purchase_timestamp'].dt.day
df['weekday'] = df['order_purchase_timestamp'].dt.weekday
df['month']=df['order_purchase_timestamp'].dt.month
df['hour']=df['order_purchase_timestamp'].dt.hour

# %%
df
# Out:
#                                 order_id                        product_id                         seller_id                       customer_id  order_item_id                customer_unique_id  shipping_limit_date order_purchase_timestamp    order_approved_at order_delivered_carrier_date order_delivered_customer_date order_estimated_delivery_date review_creation_date review_answer_timestamp    price  freight_value  customer_zip_code_prefix          customer_city customer_state  seller_zip_code_prefix         seller_city seller_state order_status  payment_sequential payment_type  payment_installments  payment_value                         review_id  review_score    review_comment_title                             review_comment_message              product_category_name  product_name_lenght  product_description_lenght  product_photos_qty  product_weight_g  product_length_cm  product_height_cm  product_width_cm  weekday  year  monthday  month  hour
# ...

# %%
trend_year=pd.DataFrame(df.groupby('year')['price'].sum().sort_values(ascending=False).round(2)).reset_index()

# %%
trend_year.set_index('year',inplace=True)

# %%
trend_year
# Out:
#            price
# year
# 2018  6753629.25
# 2017  5631733.04
# 2016    45307.41

# %%
trend_year.plot(kind='bar')

# %%
trend_hour=df.groupby('hour').agg('order_id').count()

# %%
trend_hour.plot(kind='bar')

# %%
usual_day=df.groupby(['day','order_status']).sum().order_item_id

# %%
df_usual_day=pd.DataFrame(usual_day).reset_index()

# %%
df_usual_day
# Out:
#      day order_status  order_item_id
# 0      1     canceled             15
# 1      1    delivered           3363
# 2      1     invoiced             11
# 3      1   processing             11
# 4      1      shipped             31
# 5      2     canceled             15
# 6      2    delivered           3503
# 7      2     invoiced              9
# 8      2   processing              7
# 9      2      shipped             42
# 10     3     canceled             16
# 11     3    delivered           3546
# 12     3     invoiced             15
# 13     3   processing              8
# 14     3      shipped             31
# 15     4     canceled             10
# 16     4    delivered           3712
# 17     4     invoiced              8
# 18     4   processing             19
# 19     4      shipped             52
# 20     5     canceled             22
# 21     5    delivered           3758
# 22     5     invoiced             14
# 23     5   processing             19
# ...

# %%
# Out:
#               day  order_item_id
# order_status
# approved        2              2
# canceled       31             31
# delivered      31             31
# invoiced       31             31
# processing     31             31
# shipped        31             31
# unavailable     4              4
