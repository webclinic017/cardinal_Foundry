# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as spstats
# %matplotlib inline

# %%
df_sellers = pd.read_csv('olist_sellers_dataset.csv')

# %%
df_sellers.head(4)
# Out:
#                           seller_id  seller_zip_code_prefix     seller_city  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023        campinas
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844      mogi guacu
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031  rio de janeiro
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195       sao paulo
#
#   seller_state
# 0           SP
# 1           SP
# 2           RJ
# 3           SP

# %%
df_sellers.set_index('seller_id',inplace =True)

# %%
df_sellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3095 entries, 3442f8959a84dea7ee197c632cb2df15 to 9e25199f6ef7e7c347120ff175652c3b
# Data columns (total 3 columns):
# seller_zip_code_prefix    3095 non-null int64
# seller_city               3095 non-null object
# seller_state              3095 non-null object
# dtypes: int64(1), object(2)
# memory usage: 96.7+ KB

# %%
df_sellers.seller_state.value_counts()
# Out:
# SP    1849
# PR     349
# MG     244
# SC     190
# RJ     171
# RS     129
# GO      40
# DF      30
# ES      23
# BA      19
# CE      13
# PE       9
# PB       6
# MS       5
# RN       5
# MT       4
# SE       2
# RO       2
# PA       1
# AC       1
# PI       1
# MA       1
# AM       1
# Name: seller_state, dtype: int64

# %%
df_cust=pd.read_csv('olist_customers_dataset.csv')

# %%
df_cust.head(4)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP

# %%
df_cust.customer_unique_id.value_counts()
# Out:
# 8d50f5eadf50201ccdcedfb9e2ac8455    17
# 3e43e6105506432c953e165fb2acf44c     9
# 6469f99c1f9dfae7733b25662e7f1782     7
# ca77025e7201e3b30c44b472ff346268     7
# 1b6c7548a2a1f9037c1fd3ddfed95f33     7
# dc813062e0fc23409cd255f7f53c7074     6
# 47c1a3033b8b77b3ab6e109eb4d5fdf3     6
# f0e310a6839dce9de1638e0fe5ab282a     6
# de34b16117594161a6a89c50b289d35a     6
# 63cfc61cee11cbe306bff5857d00bfe4     6
# 12f5d6e1cbf93dafd9dcc19095df0b3d     6
# 35ecdf6858edc6427223b64804cf028e     5
# 74cb1ad7e6d5674325c1f99b5ea30d82     5
# 4e65032f1f574189fb793bac5a867bbc     5
# 394ac4de8f3acb14253c177f0e15bc58     5
# 56c8638e7c058b98aae6d74d2dd6ea23     5
# fe81bb32c243a86b2f86fbf053fe6140     5
# 5e8f38a9a1c023f3db718edcf926a2db     5
# b4e4f24de1e8725b74e4a1f4975116ed     5
# c8460e4251689ba205045f3ea17884a1     4
# a7657330b1c135f3acd420326e335b2c     4
# c37cc6c1a59d81460a3059744f7ada1c     4
# b8b3c435a58aebd788a477bed8342910     4
# 25a560b9a6006157838aab1bdbd68624     4
# ...

# %%
df_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99441 entries, 06b8999e2fba1a1fbc88172c00ba8bc7 to 274fa6071e5e17fe303b9748641082c8
# Data columns (total 4 columns):
# customer_unique_id          99441 non-null object
# customer_zip_code_prefix    99441 non-null int64
# customer_city               99441 non-null object
# customer_state              99441 non-null object
# dtypes: int64(1), object(3)
# memory usage: 3.8+ MB

# %%
df_prod = pd.read_csv('olist_products_dataset.csv')

# %%
df_prod
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# 5      41d3672d4792049fa1779bb35283ed13              instrumentos_musicais
# 6      732bd381ad09e530fe0a5f457d81becb                         cool_stuff
# 7      2548af3e6e77a690cf3eb6368e9ab61e                   moveis_decoracao
# 8      37cc742be07708b53a98702e77a21a02                   eletrodomesticos
# 9      8c92109888e8cdf9d66dc7e463025574                         brinquedos
# 10     14aa47b7fe5c25522b47b4b29c98dcb9                    cama_mesa_banho
# ...

# %%
df_prod.set_index('product_id',inplace=True)

# %%
df_prod
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32951 entries, 1e9e8ef04dbcff4541ed26657ea517e5 to 106392145fca363410d287a815be6de4
# Data columns (total 8 columns):
# product_category_name         32341 non-null object
# product_name_lenght           32341 non-null float64
# product_description_lenght    32341 non-null float64
# product_photos_qty            32341 non-null float64
# product_weight_g              32949 non-null float64
# product_length_cm             32949 non-null float64
# product_height_cm             32949 non-null float64
# product_width_cm              32949 non-null float64
# dtypes: float64(7), object(1)
# memory usage: 2.3+ MB

# %%
df_prod[df_prod.isna().any(axis=1)].nunique()
# Out:
# product_category_name           1
# product_name_lenght             1
# product_description_lenght      1
# product_photos_qty              1
# product_weight_g              145
# product_length_cm              54
# product_height_cm              49
# product_width_cm               47
# dtype: int64

# %%
df_order = pd.read_csv('olist_order_items_dataset.csv')

# %%
df_order.head(4)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79

# %%
df_order.set_index('order_id',inplace=True)

# %%
df_order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 112650 entries, 00010242fe8c5a6d1ba2dd792cb16214 to fffe41c64501cc87c801fd61db3f6244
# Data columns (total 6 columns):
# order_item_id          112650 non-null int64
# product_id             112650 non-null object
# seller_id              112650 non-null object
# shipping_limit_date    112650 non-null object
# price                  112650 non-null float64
# freight_value          112650 non-null float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
df_order.freight_value.value_counts()
# Out:
# 15.10     3707
# 7.78      2262
# 14.10     1875
# 11.85     1846
# 18.23     1575
# 7.39      1521
# 16.11     1152
# 15.23     1010
# 8.72       921
# 16.79      873
# 14.52      848
# 12.79      799
# 10.96      723
# 9.34       687
# 17.60      601
# 17.67      594
# 12.69      575
# 15.11      451
# 12.48      436
# 11.73      434
# 15.79      415
# 8.88       408
# 13.37      408
# 17.63      401
# 19.32      390
# 8.29       388
# 0.00       383
# 8.27       371
# 25.63      370
# 7.87       363
#           ...
# 72.05        1
# 109.73       1
# 50.26        1
# 74.59        1
# 95.78        1
# 46.85        1
# 6.46         1
# 144.09       1
# 51.17        1
# 56.64        1
# 37.33        1
# 3.24         1
# 55.90        1
# 104.42       1
# 55.83        1
# 35.89        1
# 53.22        1
# 65.41        1
# 110.82       1
# 127.22       1
# 75.26        1
# 5.20         1
# 81.05        1
# 101.17       1
# 63.25        1
# 57.00        1
# 51.47        1
# ...

# %%
df_purchase= pd.read_csv('olist_orders_dataset.csv')

# %%
df_purchase.set_index('customer_id',inplace=True)

# %%
df_purchase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99441 entries, 9ef432eb6251297304e76186b10a928d to edb027a75a1449115f6b43211ae02a24
# Data columns (total 7 columns):
# order_id                         99441 non-null object
# order_status                     99441 non-null object
# order_purchase_timestamp         99441 non-null object
# order_approved_at                99281 non-null object
# order_delivered_carrier_date     97658 non-null object
# order_delivered_customer_date    96476 non-null object
# order_estimated_delivery_date    99441 non-null object
# dtypes: object(7)
# memory usage: 6.1+ MB

# %%
df_purchase_cust=df_purchase.merge(df_cust,how='inner', on='customer_id')

# %%
df_purchase_cust.head(4)
# Out:
#                                                           order_id  \
# customer_id
# 9ef432eb6251297304e76186b10a928d  e481f51cbdc54678b7cc49136f2d6af7
# b0830fb4747a6c6d20dea0b8c802d7ef  53cdb2fc8bc7dce0b6741e2150273451
# 41ce2a54c0b03bf3443c3d931a367089  47770eb9100c2d0c44946d9cf07ec65d
# f88197465ea7920adcdbec7375364d82  949d5b44dbf5de918fe9c16f97b45f8a
#
#                                  order_status order_purchase_timestamp  \
# customer_id
# 9ef432eb6251297304e76186b10a928d    delivered      2017-10-02 10:56:33
# b0830fb4747a6c6d20dea0b8c802d7ef    delivered      2018-07-24 20:41:37
# 41ce2a54c0b03bf3443c3d931a367089    delivered      2018-08-08 08:38:49
# f88197465ea7920adcdbec7375364d82    delivered      2017-11-18 19:28:06
#
#                                     order_approved_at  \
# customer_id
# 9ef432eb6251297304e76186b10a928d  2017-10-02 11:07:15
# b0830fb4747a6c6d20dea0b8c802d7ef  2018-07-26 03:24:27
# 41ce2a54c0b03bf3443c3d931a367089  2018-08-08 08:55:23
# ...

# %%
df_purchase_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99441 entries, 9ef432eb6251297304e76186b10a928d to edb027a75a1449115f6b43211ae02a24
# Data columns (total 11 columns):
# order_id                         99441 non-null object
# order_status                     99441 non-null object
# order_purchase_timestamp         99441 non-null object
# order_approved_at                99281 non-null object
# order_delivered_carrier_date     97658 non-null object
# order_delivered_customer_date    96476 non-null object
# order_estimated_delivery_date    99441 non-null object
# customer_unique_id               99441 non-null object
# customer_zip_code_prefix         99441 non-null int64
# customer_city                    99441 non-null object
# customer_state                   99441 non-null object
# dtypes: int64(1), object(10)
# memory usage: 9.1+ MB

# %%
df_purchase_cust[df_purchase_cust.isna().any(axis=1)].customer_state.value_counts()
# Out:
# SP    1257
# RJ     501
# MG     283
# BA     124
# RS     124
# PR     122
# SC      90
# GO      63
# DF      60
# PE      59
# CE      58
# ES      38
# MA      31
# PA      29
# MT      21
# PB      19
# PI      19
# AL      16
# SE      15
# MS      14
# RN      11
# RO      10
# TO       6
# RR       5
# AM       3
# AP       1
# AC       1
# Name: customer_state, dtype: int64

# %%
df_order.reset_index(inplace=True)

# %%
df_order.set_index('seller_id',inplace=True)

# %%
df_order_seller=df_order.merge(df_sellers,how='inner', on='seller_id')

# %%
df_order_seller.head(4)
# Out:
#                                                           order_id  \
# seller_id
# 48436dade18ac8b2bce089ec2a041202  00010242fe8c5a6d1ba2dd792cb16214
# 48436dade18ac8b2bce089ec2a041202  0188777fe321843a18be24a6e9aa1e53
# 48436dade18ac8b2bce089ec2a041202  0191bbb5166d4b9a68df11797d5acfa9
# 48436dade18ac8b2bce089ec2a041202  03054d8a8eefc2981cfad06f58e27979
#
#                                   order_item_id  \
# seller_id
# 48436dade18ac8b2bce089ec2a041202              1
# 48436dade18ac8b2bce089ec2a041202              1
# 48436dade18ac8b2bce089ec2a041202              1
# 48436dade18ac8b2bce089ec2a041202              1
#
#                                                         product_id  \
# seller_id
# 48436dade18ac8b2bce089ec2a041202  4244733e06e7ecb4970a6e2683c13e61
# 48436dade18ac8b2bce089ec2a041202  436c8d57ff8d4aa254318e9bd9b48c83
# 48436dade18ac8b2bce089ec2a041202  ec02a5d380128f7a188e9ce8f3ddd832
# 48436dade18ac8b2bce089ec2a041202  3e31fd1419cc4cd6adad1925e72e3a03
#
# ...

# %%
df_order_seller.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 112650 entries, 48436dade18ac8b2bce089ec2a041202 to 3e35a8bb43569389d3cebef0ce820f69
# Data columns (total 9 columns):
# order_id                  112650 non-null object
# order_item_id             112650 non-null int64
# product_id                112650 non-null object
# shipping_limit_date       112650 non-null object
# price                     112650 non-null float64
# freight_value             112650 non-null float64
# seller_zip_code_prefix    112650 non-null int64
# seller_city               112650 non-null object
# seller_state              112650 non-null object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 8.6+ MB

# %%
df_order_seller.describe(
# Out:
#        order_item_id          price  freight_value  seller_zip_code_prefix
# count  112650.000000  112650.000000  112650.000000           112650.000000
# mean        1.197834     120.653739      19.990320            24439.170431
# std         0.705124     183.633928      15.806405            27596.030909
# min         1.000000       0.850000       0.000000             1001.000000
# 25%         1.000000      39.900000      13.080000             6429.000000
# 50%         1.000000      74.990000      16.260000            13568.000000
# 75%         1.000000     134.900000      21.150000            27930.000000
# max        21.000000    6735.000000     409.680000            99730.000000

# %%
df_payment=pd.read_csv('olist_order_payments_dataset.csv')

# %%
df_payment.payment_sequential.value_counts()
# Out:
# 1     99360
# 2      3039
# 3       581
# 4       278
# 5       170
# 6       118
# 7        82
# 8        54
# 9        43
# 10       34
# 11       29
# 12       21
# 13       13
# 14       10
# 15        8
# 16        6
# 17        6
# 18        6
# 19        6
# 20        4
# 21        4
# 22        3
# 23        2
# 24        2
# 25        2
# 26        2
# 28        1
# 27        1
# 29        1
# Name: payment_sequential, dtype: int64

# %%
df_payment.set_index('order_id',inplace=True)

# %%
df_payment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 103886 entries, b81ef226f3fe1789b1e8b2acac839d17 to 28bbae6599b09d39ca406b747b6632b1
# Data columns (total 4 columns):
# payment_sequential      103886 non-null int64
# payment_type            103886 non-null object
# payment_installments    103886 non-null int64
# payment_value           103886 non-null float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 4.0+ MB

# %%
df_review= pd.read_csv('olist_order_reviews_dataset.csv')

# %%
df_review.head(4)
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
#
#    review_score review_comment_title                 review_comment_message  \
# 0             4                  NaN                                    NaN
# 1             5                  NaN                                    NaN
# 2             5                  NaN                                    NaN
# 3             5                  NaN  Recebi bem antes do prazo estipulado.
#
#   review_creation_date review_answer_timestamp
# 0  2018-01-18 00:00:00     2018-01-18 21:46:59
# 1  2018-03-10 00:00:00     2018-03-11 03:05:13
# 2  2018-02-17 00:00:00     2018-02-18 14:36:24
# ...

# %%
df_review.set_index('order_id',inplace=True)

# %%
df_payment_review=df_payment.merge(df_review,how='inner', on='order_id')

# %%
df_order_seller.reset_index(inplace=True)

# %%
df_order_seller.set_index('order_id',inplace=True)

# %%
df_order_seller_payment_review=df_order_seller.merge(df_payment_review,how='inner', on='order_id')

# %%
df_order_seller_payment_review.head(4)
# Out:
#                                                          seller_id  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214  48436dade18ac8b2bce089ec2a041202
# 0188777fe321843a18be24a6e9aa1e53  48436dade18ac8b2bce089ec2a041202
# 0191bbb5166d4b9a68df11797d5acfa9  48436dade18ac8b2bce089ec2a041202
# 03054d8a8eefc2981cfad06f58e27979  48436dade18ac8b2bce089ec2a041202
#
#                                   order_item_id  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214              1
# 0188777fe321843a18be24a6e9aa1e53              1
# 0191bbb5166d4b9a68df11797d5acfa9              1
# 03054d8a8eefc2981cfad06f58e27979              1
#
#                                                         product_id  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 0188777fe321843a18be24a6e9aa1e53  436c8d57ff8d4aa254318e9bd9b48c83
# 0191bbb5166d4b9a68df11797d5acfa9  ec02a5d380128f7a188e9ce8f3ddd832
# 03054d8a8eefc2981cfad06f58e27979  3e31fd1419cc4cd6adad1925e72e3a03
#
# ...

# %%
df_order_seller_payment_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 118315 entries, 00010242fe8c5a6d1ba2dd792cb16214 to ff701a7c869ad21de22a6994237c8a00
# Data columns (total 19 columns):
# seller_id                  118315 non-null object
# order_item_id              118315 non-null int64
# product_id                 118315 non-null object
# shipping_limit_date        118315 non-null object
# price                      118315 non-null float64
# freight_value              118315 non-null float64
# seller_zip_code_prefix     118315 non-null int64
# seller_city                118315 non-null object
# seller_state               118315 non-null object
# payment_sequential         118315 non-null int64
# payment_type               118315 non-null object
# payment_installments       118315 non-null int64
# payment_value              118315 non-null float64
# review_id                  118315 non-null object
# review_score               118315 non-null int64
# review_comment_title       14089 non-null object
# ...

# %%
df_order_seller_payment_review_purchase_cust=df_order_seller_payment_review.merge(df_purchase_cust,how='inner', on='order_id')

# %%
df_order_seller_payment_review_purchase_cust_product=df_order_seller_payment_review_purchase_cust.merge(df_prod,how='inner', on='product_id')

# %%
df_order_seller_payment_review_purchase_cust_product.to_csv('df_main.csv',index=False)

# %%
df = pd.read_csv('df_main.csv')

# %%
df.order_item_id.value_counts()
# Out:
# 1     103652
# 2      10316
# 3       2395
# 4        995
# 5        472
# 6        265
# 7         61
# 8         37
# 9         29
# 10        26
# 11        18
# 12        13
# 13         8
# 14         7
# 15         5
# 20         3
# 16         3
# 17         3
# 18         3
# 19         3
# 21         1
# Name: order_item_id, dtype: int64

# %%
df
# Out:
#                               product_id                          order_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  00010242fe8c5a6d1ba2dd792cb16214
# 1       4244733e06e7ecb4970a6e2683c13e61  130898c0987d1801452a8ed92a670612
# 2       4244733e06e7ecb4970a6e2683c13e61  532ed5e14e24ae1f0d735b91524b98b9
# 3       4244733e06e7ecb4970a6e2683c13e61  6f8c31653edb8c83e1a739408b5ff750
# 4       4244733e06e7ecb4970a6e2683c13e61  7d19f4ef4d04461989632411b7e588b9
# 5       4244733e06e7ecb4970a6e2683c13e61  a0f9acf0b6294ed8561e32cde1a966bc
# 6       4244733e06e7ecb4970a6e2683c13e61  bbf796534aaf9c59f8da8c7982db56e0
# 7       4244733e06e7ecb4970a6e2683c13e61  c9ef97d2854afe64a3b4488bc2836af6
# 8       4244733e06e7ecb4970a6e2683c13e61  df2d910b8b5e5f461f67043489f9569d
# 9       4244733e06e7ecb4970a6e2683c13e61  df2d910b8b5e5f461f67043489f9569d
# 10      4244733e06e7ecb4970a6e2683c13e61  df2d910b8b5e5f461f67043489f9569d
# ...
