# %% [markdown]
# ## Cleaning Data

# %%
import pandas as pd

# %%
import numpy as np

# %%
titanic= pd.read_csv('titanic_imp.csv')

# %%
titanic.head()
# Out:
#   Survived  Class  Gender   Age  SipSp  ParCh      Fare Emb Deck
# 0        0      3    male  22.0      1      0     $7.25   S  NaN
# 1        1      1  female  38.0      1      0  $71.2833   C    C
# 2        1      3  female  26.0      0      0    $7.925   S  NaN
# 3        1      1  female  35.0      1      0     $53.1   S    C
# 4        0      3    male  35.0      0      0     $8.05   S  NaN

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894 entries, 0 to 893
# Data columns (total 9 columns):
# Survived    894 non-null int32
# Class       894 non-null int64
# Gender      894 non-null object
# Age         758 non-null object
# SipSp       894 non-null int64
# ParCh       894 non-null int64
# Fare        894 non-null float64
# Emb         892 non-null object
# Deck        203 non-null object
# dtypes: float64(1), int32(1), int64(3), object(4)
# memory usage: 59.4+ KB

# %%
titanic.describe()
# Out:
#          Survived       Class       SipSp       ParCh        Fare
# count  894.000000  894.000000  894.000000  894.000000  894.000000
# mean     0.382550    2.309843    0.522371    0.381432   32.132824
# std      0.486282    0.835370    1.101283    0.805171   49.625396
# min      0.000000    1.000000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000    0.000000    7.903100
# 50%      0.000000    3.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000    8.000000    6.000000  512.329200

# %%
titanic[['Survived', 'Gender', 'Age', 'Fare', 'Emb','Deck']].describe()
# Out:
#        Survived Gender           Age   Fare  Emb Deck
# count       894    894           758    894  892  203
# unique        4      2            92    248    3    7
# top           0   male  Missing Data  $8.05    S    C
# freq        551    580            41     43  647   59

# %%
titanic.Survived.unique()
# Out:
# array(['0', '1', 1, 0], dtype=object)

# %%
titanic.Survived.value_counts()#data type is still a mess that we tackle later.
# Out:
# 0    551
# 1    341
# 1      1
# 0      1
# Name: Survived, dtype: int64

# %%
titanic.Survived.replace(to_replace= ['yes','no'],value= [1,0], inplace=True)

# %%
pd.to_numeric(titanic.Fare)#Method one.
# Out:
# 0        7.2500
# 1       71.2833
# 2        7.9250
# 3       53.1000
# 4        8.0500
# 5        8.4583
# 6       51.8625
# 7       21.0750
# 8       11.1333
# 9       30.0708
# 10      16.7000
# 11      26.5500
# 12       8.0500
# 13      31.2750
# 14       7.8542
# 15      16.0000
# 16      29.1250
# 17      13.0000
# 18      18.0000
# 19       7.2250
# 20      26.0000
# 21      13.0000
# 22       8.0292
# 23      35.5000
# 24      21.0750
# 25      31.3875
# 26       7.2250
# 27     263.0000
# 28       7.8792
# 29       7.8958
#          ...
# 864     13.0000
# 865     13.0000
# 866     13.8583
# 867     50.4958
# 868      9.5000
# 869     11.1333
# 870      7.8958
# 871     52.5542
# 872      5.0000
# 873      9.0000
# 874     24.0000
# 875      7.2250
# 876      9.8458
# 877      7.8958
# 878      7.8958
# 879     83.1583
# 880     26.0000
# 881      7.8958
# 882     10.5167
# 883     10.5000
# 884      7.0500
# 885     29.1250
# 886     13.0000
# 887     30.0000
# ...

# %%
titanic.Fare =titanic.Fare.str.replace('$','')#we will take care data type latar.

# %%
titanic.Fare=titanic.Fare.astype('float')#method two.

# %%
summer= pd.read_csv('summer_imp.csv')
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# 5      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 7      1896  Athens   Aquatics             Swimming
# 8      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# 10     1896  Athens   Aquatics             Swimming
# 11     1896  Athens  Athletics            Athletics
# 12     1896  Athens  Athletics            Athletics
# 13     1896  Athens  Athletics            Athletics
# 14     1896  Athens  Athletics            Athletics
# 15     1896  Athens  Athletics            Athletics
# 16     1896  Athens  Athletics            Athletics
# ...

# %%
titanic.Survived = titanic.Survived.astype('int')

# %%
titanic.Age = titanic.Age.astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-2f7b117c02ee> in <module>
# ----> 1 titanic.Age = titanic.Age.astype('float')
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5001                                          **kwargs)
#    5002             return self._constructor(new_data).__finalize__(self)
#    5003
#
# ...

# %%
#cant do operations on 'Athlete Name' with space in bet.
summer.rename(columns={'Athlete Name':'Athlete_Name'},inplace=True)

# %%
summer.Medal.value_counts()
# Out:
# Gold          10483
# Bronze        10372
# Silver        10311
# Gold Medal        4
# Name: Medal, dtype: int64

# %%
summer.Medal.replace(to_replace='Gold Medal', value = 'Gold', inplace =True)

# %%
summer.iloc[:,1:].describe()#inspect all non-numeric columns.Simply slice.
# Out:
#           City     Sport Discipline       Athlete_Name Country Gender  \
# count    31170     31170      31170              31170   31166  31170
# unique      22        43         67              22763     147      2
# top     London  Aquatics  Athletics   PHELPS, Michael      USA    Men
# freq      3567      4170       3639                 22    4586  22751
#
#            Event  Medal
# count      31170  31170
# unique       666      3
# top     Football   Gold
# freq        1497  10487

# %%
summer.Athlete_Name = summer.Athlete_Name.str.title()#No inplace available.

# %%
summer.loc[summer.Athlete_Name== 'Hajos, Alfred']#can't filter specific data.Why?Works now.
# Out:
#    Year    City     Sport Discipline   Athlete_Name Country Gender  \
# 0  1896  Athens  Aquatics   Swimming  Hajos, Alfred     HUN    Men
# 6  1896  Athens  Aquatics   Swimming  Hajos, Alfred     HUN    Men
#
#              Event       Medal
# 0   100M Freestyle  Gold Medal
# 6  1200M Freestyle  Gold Medal

# %%
summer.iloc[0,4]#damn, there are hidden spaces within strings.
# Out:
# ' Hajos, Alfred '

# %%
summer.loc[summer.Athlete_Name.str.contains('Hajos, Alfred')]#now it works.
# Out:
#    Year    City     Sport Discipline     Athlete_Name Country Gender  \
# 0  1896  Athens  Aquatics   Swimming   Hajos, Alfred      HUN    Men
# 6  1896  Athens  Aquatics   Swimming   Hajos, Alfred      HUN    Men
#
#              Event       Medal
# 0   100M Freestyle  Gold Medal
# 6  1200M Freestyle  Gold Medal

# %%
#to remove white spaces from left and right sides,
summer.Athlete_Name=summer.Athlete_Name.str.strip()#no inplace available.

# %% [markdown]
# ### NA values

# %%
sales = pd.read_csv('sales.csv',index_col=0)

# %%
sales.iloc[1,1]=None#creating some more missing values.Not the best way though.

# %%
sales.iloc[2,2] = np.nan

# %%
sales.iloc[0,-1]=np.nan

# %%
#sometimes there are whitespaces instead of NaN.Sometimes,literal 'no data' string.
sales
# Out:
#         Mon   Tue   Wed   Thu   Fri
# Steven   34  27.0  15.0   NaN   NaN
# Mike     45   NaN  74.0  87.0  12.0
# Andi     17  33.0   NaN   8.0  29.0
# Paul     87  67.0  27.0  45.0   7.0

# %%
 titanic.isna().sum(axis=0)#sum per column(axis=0),sum per row(axis=1). True becomes 1 and False 0
# Out:
# Survived      0
# Class         0
# Gender        0
# Age         136
# SipSp         0
# ParCh         0
# Fare          0
# Emb           2
# Deck        691
# dtype: int64

# %%
titanic.isna().any(axis=1)#all rows check for Missing value. by default axis=0.
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
# 5       True
# 6      False
# 7       True
# 8       True
# 9       True
# 10     False
# 11     False
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21     False
# 22      True
# 23     False
# 24      True
# 25      True
# 26      True
# 27     False
# 28      True
# 29      True
#        ...
# 864     True
# 865     True
# 866     True
# 867    False
# 868     True
# 869     True
# 870     True
# 871    False
# 872    False
# 873     True
# 874     True
# 875     True
# 876     True
# 877     True
# 878     True
# 879    False
# 880     True
# 881     True
# 882     True
# 883     True
# 884     True
# 885     True
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# 891     True
# 892     True
# 893     True
# Length: 894, dtype: bool

# %%
#what doesn't work.
#titanic.loc[titanic.isna()]
# titanic[titanic.isna().any(axis=0)]
titanic[titanic.isna().any(axis=1)]#only this works.
# Out:
#      Survived  Class  Gender           Age  SipSp  ParCh      Fare Emb Deck
# 0           0      3    male          22.0      1      0    7.2500   S  NaN
# 2           1      3  female          26.0      0      0    7.9250   S  NaN
# 4           0      3    male          35.0      0      0    8.0500   S  NaN
# 5           0      3    male  Missing Data      0      0    8.4583   Q  NaN
# 7           0      3    male           2.0      3      1   21.0750   S  NaN
# 8           1      3  female          27.0      0      2   11.1333   S  NaN
# 9           1      2  female          14.0      1      0   30.0708   C  NaN
# 12          0      3    male          20.0      0      0    8.0500   S  NaN
# 13          0      3    male          39.0      1      5   31.2750   S  NaN
# 14          0      3  female          14.0      0      0    7.8542   S  NaN
# 15          1      2  female          55.0      0      0   16.0000   S  NaN
# ...

# %%
titanic.notna().sum()
# Out:
# Survived    894
# Class       894
# Gender      894
# Age         758
# SipSp       894
# ParCh       894
# Fare        894
# Emb         892
# Deck        203
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12,8)) #to visualize missing values.
sns.heatmap(titanic.notna())
plt.show()

# %%
titanic.Age.value_counts(dropna=False)#one more method. Inconsistency with'Missing Data' string.
# Out:
# NaN             136
# Missing Data     41
# 24.0             31
# 22.0             27
# 18.0             26
# 19.0             25
# 30.0             25
# 28.0             25
# 21.0             24
# 36.0             23
# 25.0             22
# 29.0             20
# 32.0             18
# 26.0             18
# 27.0             18
# 35.0             18
# 16.0             17
# 31.0             17
# 34.0             16
# 20.0             15
# 33.0             15
# 23.0             15
# 39.0             14
# 17.0             13
# 40.0             13
# 42.0             12
# 45.0             12
# 38.0             11
# 4.0              10
# 2.0              10
#                ...
# 0.83              2
# 59.0              2
# 13.0              2
# 45.5              2
# 0.75              2
# 32.5              2
# 71.0              2
# 40.5              2
# 63.0              2
# 28.5              2
# 70.0              2
# 102               1
# 250               1
# 36.5              1
# ...

# %%
titanic.Age.replace(to_replace='Missing Data', value= np.nan,inplace=True)

# %%
titanic.Age=titanic.Age.astype('float')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894 entries, 0 to 893
# Data columns (total 9 columns):
# Survived    894 non-null int32
# Class       894 non-null int64
# Gender      894 non-null object
# Age         717 non-null float64
# SipSp       894 non-null int64
# ParCh       894 non-null int64
# Fare        894 non-null float64
# Emb         892 non-null object
# Deck        203 non-null object
# dtypes: float64(2), int32(1), int64(3), object(3)
# memory usage: 59.4+ KB

# %%
titanic[titanic.Emb.isna().any(axis=1)]#doesn't work because this is series, not df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-153-a3c26eedbed4> in <module>
# ----> 1 titanic[titanic.Emb.isna().any(axis=1)]#doesn't work because this is series, not df
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in logical_func(self, axis, bool_only, skipna, level, **kwargs)
#    9686                                       skipna=skipna)
#    9687         return self._reduce(f, name, axis=axis, skipna=skipna,
# -> 9688                             numeric_only=bool_only, filter_type='bool')
#    9689
#    9690     return set_function_name(logical_func, name, cls)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3214             # Validate that 'axis' is consistent with Series's single axis.
#    3215             if axis is not None:
# ...

# %%
titanic[titanic.Emb.isna()]#works because this is series.
# Out:
#      Survived  Class  Gender   Age  SipSp  ParCh  Fare  Emb Deck
# 61          1      1  female  38.0      0      0  80.0  NaN    B
# 829         1      1  female  62.0      0      0  80.0  NaN    B

# %%
titanic.Age.value_counts(dropna=False)#Pandas works with NaN values.
# Out:
# NaN        177
#  24.00      31
#  22.00      27
#  18.00      26
#  30.00      25
#  19.00      25
#  28.00      25
#  21.00      24
#  36.00      23
#  25.00      22
#  29.00      20
#  27.00      18
#  35.00      18
#  26.00      18
#  32.00      18
#  31.00      17
#  16.00      17
#  34.00      16
#  20.00      15
#  33.00      15
#  23.00      15
#  39.00      14
#  17.00      13
#  40.00      13
#  42.00      12
#  45.00      12
#  38.00      11
#  4.00       10
#  2.00       10
#  50.00      10
#           ...
#  0.75        2
#  13.00       2
#  30.50       2
#  64.00       2
#  10.00       2
#  70.00       2
#  0.83        2
#  28.50       2
#  71.00       2
#  63.00       2
#  59.00       2
#  0.92        1
#  34.50       1
#  24.50       1
#  0.67        1
#  70.50       1
#  74.00       1
#  250.00      1
#  36.50       1
#  80.00       1
#  53.00       1
#  66.00       1
#  55.50       1
#  23.50       1
#  20.50       1
#  102.00      1
#  490.00      1
# ...

# %%
titanic.Age.mean(skipna=True)# Pandas is robust.
# Out:
# 30.718507670850766

# %%
titanic.shape
# Out:
# (894, 9)

# %%
titanic.dropna().shape#we can drop and see how shape differs.
# Out:
# (182, 9)

# %%
titanic.dropna(axis=0,how='any').shape#basically same as above
# Out:
# (182, 9)

# %%
titanic.dropna(axis=1, how ='any').shape#dropping columns with any missing value.
# Out:
# (894, 6)

# %%
titanic.dropna(axis=0, thresh=8).shape#we have some 150 rows with 2 or more misssing values.
# Out:
# (736, 9)

# %%
titanic.dropna(axis=1, thresh=500).shape#we drop a column with less than 500 missing value.
# Out:
# (894, 8)

# %%
#dropping all rows with any missing values.
titanic.dropna(axis=0,subset=['Survived', 'Class', 'Gender','Age'],thresh=4).shape
# Out:
# (717, 8)

# %%
mean = round (titanic.Age.mean(),1)

# %%
titanic.Age.fillna(mean, inplace=True)

# %%
summer[summer.isna().any(axis=1)]#nothing else works.This is whole df.
# Out:
#        Year    City          Sport           Discipline     Athlete_Name  \
# 29608  2012  London      Athletics            Athletics          Pending
# 31077  2012  London  Weightlifting        Weightlifting          Pending
# 31096  2012  London  Weightlifting        Weightlifting          Pending
# 31115  2012  London      Wrestling  Wrestling Freestyle  Kudukhov, Besik
#
#       Country Gender     Event   Medal
# 29608     NaN  Women     1500M    Gold
# 31077     NaN  Women      63KG    Gold
# 31096     NaN    Men      94KG  Silver
# 31115     NaN    Men  Wf 60 KG  Silver

# %%
summer.dropna(inplace=True)

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31166 entries, 0 to 31169
# Data columns (total 9 columns):
# Year            31166 non-null int64
# City            31166 non-null object
# Sport           31166 non-null object
# Discipline      31166 non-null object
# Athlete_Name    31166 non-null object
# Country         31166 non-null object
# Gender          31166 non-null object
# Event           31166 non-null object
# Medal           31166 non-null object
# dtypes: int64(1), object(8)
# memory usage: 2.4+ MB

# %% [markdown]
# ### Duplicates

# %%
alphabet = pd.DataFrame(["a", "b", "c", "c", "d", "e", "f", "g", "g", "g"], columns = ["Alphabet"])

# %%
alphabet[alphabet.duplicated(keep='first')]
# Out:
#   Alphabet
# 3        c
# 8        g
# 9        g

# %%
titanic.duplicated(keep='first',subset =['Survived','Class']).sum()
# Out:
# 888

# %%
summer[summer.duplicated(keep=False)]
# Out:
#        Year       City      Sport Discipline           Athlete_Name Country  \
# 2068   1912  Stockholm  Athletics  Athletics  Lelong, Charles Louis     FRA
# 2069   1912  Stockholm  Athletics  Athletics  Lelong, Charles Louis     FRA
# 12252  1968     Mexico    Fencing    Fencing          Kalmar, Janos     HUN
# 12253  1968     Mexico    Fencing    Fencing          Kalmar, Janos     HUN
# 15595  1980     Moscow     Boxing     Boxing       Mustafov, Ismail     BUL
# 15596  1980     Moscow     Boxing     Boxing       Mustafov, Ismail     BUL
# 16101  1980     Moscow     Hockey     Hockey           Singh, Singh     IND
# 16102  1980     Moscow     Hockey     Hockey           Singh, Singh     IND
# 21832  1996    Atlanta   Baseball   Baseball         Scull, Antonio     CUB
# 21833  1996    Atlanta   Baseball   Baseball         Scull, Antonio     CUB
# 28677  2008    Beijing     Rowing     Rowing      Volpenhein, Bryan     USA
# ...

# %%
summer.loc[(summer.Sport=='Basketball') & (summer.Year== 2012)]#exploring duplicates.
# Out:
#        Year    City       Sport  Discipline            Athlete_Name Country  \
# 29801  2012  London  Basketball  Basketball        Anthony, Carmelo     USA
# 29802  2012  London  Basketball  Basketball            Bryant, Kobe     USA
# 29803  2012  London  Basketball  Basketball         Chandler, Tyson     USA
# 29804  2012  London  Basketball  Basketball          Davis, Anthony     USA
# 29805  2012  London  Basketball  Basketball           Durant, Kevin     USA
# 29806  2012  London  Basketball  Basketball           Harden, James     USA
# 29807  2012  London  Basketball  Basketball         Iguodala, Andre     USA
# 29808  2012  London  Basketball  Basketball           James, Lebron     USA
# 29809  2012  London  Basketball  Basketball             Love, Kevin     USA
# 29810  2012  London  Basketball  Basketball             Paul, Chris     USA
# 29811  2012  London  Basketball  Basketball      Westbrook, Russell     USA
# ...

# %%
alphabet.drop_duplicates(inplace=True)

# %%
alphabet
# Out:
#   Alphabet
# 0        a
# 1        b
# 2        c
# 4        d
# 5        e
# 6        f
# 7        g

# %% [markdown]
# ### Outliers

# %%
titanic.describe()
# Out:
#          Survived       Class         Age       SipSp       ParCh        Fare
# count  894.000000  894.000000  894.000000  894.000000  894.000000  894.000000
# mean     0.382550    2.309843   30.714843    0.522371    0.381432   32.132824
# std      0.486282    0.835370   21.554721    1.101283    0.805171   49.625396
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.903100
# 50%      0.000000    3.000000   30.700000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000  490.000000    8.000000    6.000000  512.329200

# %%
plt.figure(figsize=(12,8))
titanic.boxplot('Age')
plt.show()

# %%
plt.figure(figsize=(12,8))
titanic.Age.plot()
plt.show()

# %%
titanic.Age.sort_values(ascending=False)
# Out:
# 453    490.00
# 785    250.00
# 217    102.00
# 630     80.00
# 851     74.00
# 96      71.00
# 493     71.00
# 116     70.50
# 672     70.00
# 745     70.00
# 33      66.00
# 280     65.00
# 54      65.00
# 456     65.00
# 438     64.00
# 545     64.00
# 483     63.00
# 275     63.00
# 252     62.00
# 829     62.00
# 570     62.00
# 555     62.00
# 326     61.00
# 625     61.00
# 170     61.00
# 684     60.00
# 366     60.00
# 694     60.00
# 587     60.00
# 94      59.00
#         ...
# 407      3.00
# 43       3.00
# 348      3.00
# 374      3.00
# 193      3.00
# 261      3.00
# 530      2.00
# 7        2.00
# 119      2.00
# 205      2.00
# 340      2.00
# 642      2.00
# 297      2.00
# 16       2.00
# 479      2.00
# 824      2.00
# 788      1.00
# 183      1.00
# 381      1.00
# 386      1.00
# 172      1.00
# 827      1.00
# 164      1.00
# 305      0.92
# 831      0.83
# 78       0.83
# 469      0.75
# 644      0.75
# 755      0.67
# 803      0.42
# ...

# %%
index_age_outlier= titanic.loc[titanic.Age>90].index

# %%
titanic.loc[titanic.Age>90,'Age'] = titanic.loc[titanic.Age>90,'Age']/10

# %%
titanic.loc[217,'Age']= 42

# %%
titanic.loc[index_age_outlier]
# Out:
#      Survived  Class Gender   Age  SipSp  ParCh     Fare Emb
# 217         0      2   male  42.0      1      0  27.0000   S
# 453         1      1   male  49.0      1      0  89.1042   C
# 785         0      3   male  25.0      0      0   7.2500   S

# %%
titanic.Fare.sort_values(ascending= False)
# Out:
# 258    512.3292
# 679    512.3292
# 737    512.3292
# 27     263.0000
# 341    263.0000
# 438    263.0000
# 88     263.0000
# 742    262.3750
# 311    262.3750
# 118    247.5208
# 299    247.5208
# 716    227.5250
# 380    227.5250
# 557    227.5250
# 700    227.5250
# 527    221.7792
# 377    211.5000
# 689    211.3375
# 779    211.3375
# 730    211.3375
# 856    164.8667
# 318    164.8667
# 332    153.4625
# 268    153.4625
# 609    153.4625
# 498    151.5500
# 305    151.5500
# 708    151.5500
# 297    151.5500
# 195    146.5208
#          ...
# 131      7.0500
# 477      7.0458
# 129      6.9750
# 804      6.9750
# 825      6.9500
# 411      6.8583
# 143      6.7500
# 654      6.7500
# 202      6.4958
# 371      6.4958
# 818      6.4500
# 843      6.4375
# 326      6.2375
# 872      5.0000
# 378      4.0125
# 263      0.0000
# 271      0.0000
# 822      0.0000
# 815      0.0000
# 277      0.0000
# 806      0.0000
# 302      0.0000
# 179      0.0000
# 674      0.0000
# ...

# %%
plt.figure(figsize=(12,8))
titanic.Fare.plot()
plt.show()

# %%
titanic.to_csv('titanic_clean.csv',index=False)

# %% [markdown]
# ### Categorical Data

# %%
titanic.nunique()
# Out:
# Survived      2
# Class         3
# Gender        2
# Age          89
# SipSp         7
# ParCh         7
# Fare        248
# Emb           3
# dtype: int64

# %%
titanic.loc[:,['Gender','Emb']].describe()
# Out:
#        Gender  Emb
# count     894  892
# unique      2    3
# top      male    S
# freq      580  647

# %%
titanic.Gender = titanic.Gender.astype('category')

# %%
titanic.Emb= titanic.Emb.astype('category')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894 entries, 0 to 893
# Data columns (total 8 columns):
# Survived    894 non-null int32
# Class       894 non-null int64
# Gender      894 non-null category
# Age         894 non-null float64
# SipSp       894 non-null int64
# ParCh       894 non-null int64
# Fare        894 non-null float64
# Emb         892 non-null category
# dtypes: category(2), float64(2), int32(1), int64(3)
# memory usage: 40.4 KB

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31166 entries, 0 to 31169
# Data columns (total 9 columns):
# Year            31166 non-null int64
# City            31166 non-null object
# Sport           31166 non-null object
# Discipline      31166 non-null object
# Athlete_Name    31166 non-null object
# Country         31166 non-null object
# Gender          31166 non-null object
# Event           31166 non-null object
# Medal           31166 non-null object
# dtypes: int64(1), object(8)
# memory usage: 2.4+ MB

# %%
summer.describe(include='O')#describe method on object type or string.
# Out:
#           City     Sport Discipline     Athlete_Name Country Gender     Event  \
# count    31166     31166      31166            31166   31166  31166     31166
# unique      22        43         67            22760     147      2       666
# top     London  Aquatics  Athletics  Phelps, Michael     USA    Men  Football
# freq      3563      4170       3638               22    4586  22749      1497
#
#         Medal
# count   31166
# unique      4
# top      Gold
# freq    10481

# %%
summer.City = summer.City.astype('category')

# %%
summer.Sport = summer.Sport.astype('category')

# %%
summer.Discipline = summer.Discipline.astype('category')

# %%
summer.Country = summer.Country.astype('category')

# %%
summer.Gender = summer.Gender.astype('category')

# %%
summer.Medal = summer.Medal.astype('category')

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31166 entries, 0 to 31169
# Data columns (total 9 columns):
# Year            31166 non-null int64
# City            31166 non-null category
# Sport           31166 non-null category
# Discipline      31166 non-null category
# Athlete_Name    31166 non-null object
# Country         31166 non-null category
# Gender          31166 non-null category
# Event           31166 non-null object
# Medal           31166 non-null category
# dtypes: category(6), int64(1), object(2)
# memory usage: 1.2+ MB
