# %% [markdown]
# # Coding Exercises (Part 13)

# %% [markdown]
# ## Complete Data Workflow A-Z: Advanced Visualization with Seaborn

# %% [markdown]
# ### Exercise 16: Seaborn

# %% [markdown]
# Now, you will have the opportunity to analyze your own dataset. <br>
# __Follow the instructions__ and insert your code! You are either requested to
# - Complete the Code and __Fill in the gaps__. Gaps are marked with "__---__" and are __placeholders__ for your code fragment.
# - Write Code completely __on your own__

# %% [markdown]
# In some exercises, you will find questions that can only be answered, if your code is correct and returns the right output! The correct answer is provided below your coding cell. There you can check whether your code is correct.

# %% [markdown]
# If you need a hint, check the __Hints Section__ at the end of this Notebook. Exercises and Hints are numerated accordingly.

# %% [markdown]
# If you need some further help or if you want to check your code, you can also check the __solutions notebook__.

# %% [markdown]
# ### Have Fun!

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Option 1: Self_guided

# %% [markdown]
# 142. __Import__ the cars dataset and __drop__ any missing values (__cars.csv__)!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cars=pd.read_csv('cars.csv')

# %%
cars.dropna(inplace=True)

# %% [markdown]
# 143. __Create__ the following plot!

# %%
sns.set(font_scale=1.5,palette='viridis')
sns.countplot(data=cars,x='model_year',hue='origin')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 144. __Create__ the following plot! Cars with the lowest __fuel efficiency__ come from...?

# %%
sns.swarmplot(data=cars,x='origin',y='mpg',color='black',dodge=True)
sns.violinplot(data=cars,x='origin',y='mpg',dodge=True)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 145. __Create__ the following plot! Do you think that the lower fuel efficiency of us cars is __statistically significant__?

# %%
sns.barplot(data=cars, x= 'origin', y='mpg',dodge=True)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 146. __Create__ the following plot! Do you think that manufacturers from __all three regions significantly increased fuel efficiency__ from 1970 till 1982?

# %%
sns.pointplot(data=cars,x= 'model_year',y='mpg',hue='origin')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 147. Create __similar plots__ (as above) with __horsepower__, __weight__ and __displacement__ on the y-axis! <br> Can you identify __differences__ in the ways how manufacturers managed to __increase fuel efficiency__?

# %%
sns.pointplot(data=cars, x='model_year',y='horsepower',hue='origin')

# %%
sns.pointplot(data=cars, x='model_year',y='weight',hue='origin')

# %%
sns.pointplot(data=cars, x='model_year',y='displacement',hue='origin')

# %%
cars['gpm']= (1/cars.mpg*100).round(2)
cars.drop(columns='mpg',inplace=True)
cars
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0            8         307.0       130.0    3504          12.0          70
# 1            8         350.0       165.0    3693          11.5          70
# 2            8         318.0       150.0    3436          11.0          70
# 3            8         304.0       150.0    3433          12.0          70
# 4            8         302.0       140.0    3449          10.5          70
# 5            8         429.0       198.0    4341          10.0          70
# 6            8         454.0       220.0    4354           9.0          70
# 7            8         440.0       215.0    4312           8.5          70
# 8            8         455.0       225.0    4425          10.0          70
# 9            8         390.0       190.0    3850           8.5          70
# 10           8         383.0       170.0    3563          10.0          70
# 11           8         340.0       160.0    3609           8.0          70
# 12           8         400.0       150.0    3761           9.5          70
# 13           8         455.0       225.0    3086          10.0          70
# 14           4         113.0        95.0    2372          15.0          70
# 15           6         198.0        95.0    2833          15.5          70
# 16           6         199.0        97.0    2774          15.5          70
# 17           6         200.0        85.0    2587          16.0          70
# 18           4          97.0        88.0    2130          14.5          70
# 19           4          97.0        46.0    1835          20.5          70
# 20           4         110.0        87.0    2672          17.5          70
# 21           4         107.0        90.0    2430          14.5          70
# 22           4         104.0        95.0    2375          17.5          70
# 23           4         121.0       113.0    2234          12.5          70
# 24           6         199.0        90.0    2648          15.0          70
# 25           8         360.0       215.0    4615          14.0          70
# 26           8         307.0       200.0    4376          15.0          70
# 27           8         318.0       210.0    4382          13.5          70
# 28           8         304.0       193.0    4732          18.5          70
# 29           4          97.0        88.0    2130          14.5          71
# ..         ...           ...         ...     ...           ...         ...
# 367          4         112.0        88.0    2605          19.6          82
# 368          4         112.0        88.0    2640          18.6          82
# 369          4         112.0        88.0    2395          18.0          82
# 370          4         112.0        85.0    2575          16.2          82
# 371          4         135.0        84.0    2525          16.0          82
# 372          4         151.0        90.0    2735          18.0          82
# 373          4         140.0        92.0    2865          16.4          82
# 375          4         105.0        74.0    1980          15.3          82
# 376          4          91.0        68.0    2025          18.2          82
# 377          4          91.0        68.0    1970          17.6          82
# 378          4         105.0        63.0    2125          14.7          82
# 379          4          98.0        70.0    2125          17.3          82
# 380          4         120.0        88.0    2160          14.5          82
# 381          4         107.0        75.0    2205          14.5          82
# 382          4         108.0        70.0    2245          16.9          82
# 383          4          91.0        67.0    1965          15.0          82
# 384          4          91.0        67.0    1965          15.7          82
# 385          4          91.0        67.0    1995          16.2          82
# 386          6         181.0       110.0    2945          16.4          82
# 387          6         262.0        85.0    3015          17.0          82
# 388          4         156.0        92.0    2585          14.5          82
# 389          6         232.0       112.0    2835          14.7          82
# 390          4         144.0        96.0    2665          13.9          82
# 391          4         135.0        84.0    2370          13.0          82
# 392          4         151.0        90.0    2950          17.3          82
# 393          4         140.0        86.0    2790          15.6          82
# 394          4          97.0        52.0    2130          24.6          82
# 395          4         135.0        84.0    2295          11.6          82
# 396          4         120.0        79.0    2625          18.6          82
# 397          4         119.0        82.0    2720          19.4          82
#
#      origin                               name    gpm
# 0       usa          chevrolet chevelle malibu   5.56
# 1       usa                  buick skylark 320   6.67
# 2       usa                 plymouth satellite   5.56
# 3       usa                      amc rebel sst   6.25
# 4       usa                        ford torino   5.88
# 5       usa                   ford galaxie 500   6.67
# 6       usa                   chevrolet impala   7.14
# 7       usa                  plymouth fury iii   7.14
# 8       usa                   pontiac catalina   7.14
# 9       usa                 amc ambassador dpl   6.67
# 10      usa                dodge challenger se   6.67
# 11      usa                 plymouth 'cuda 340   7.14
# 12      usa              chevrolet monte carlo   6.67
# 13      usa            buick estate wagon (sw)   7.14
# 14    japan              toyota corona mark ii   4.17
# 15      usa                    plymouth duster   4.55
# 16      usa                         amc hornet   5.56
# 17      usa                      ford maverick   4.76
# 18    japan                       datsun pl510   3.70
# 19   europe               vw 1131 deluxe sedan   3.85
# 20   europe                        peugeot 504   4.00
# 21   europe                        audi 100 ls   4.17
# 22   europe                           saab 99e   4.00
# 23   europe                           bmw 2002   3.85
# 24      usa                        amc gremlin   4.76
# 25      usa                          ford f250  10.00
# 26      usa                      chevrolet c20  10.00
# 27      usa                         dodge d200   9.09
# 28      usa                           ih 1200d  11.11
# 29    japan                       datsun pl510   3.70
# ..      ...                                ...    ...
# 367     usa                 chevrolet cavalier   3.57
# 368     usa           chevrolet cavalier wagon   3.70
# 369     usa          chevrolet cavalier 2-door   2.94
# 370     usa         pontiac j2000 se hatchback   3.23
# 371     usa                     dodge aries se   3.45
# 372     usa                    pontiac phoenix   3.70
# 373     usa               ford fairmont futura   4.17
# 375  europe                        vw rabbit l   2.78
# 376   japan                 mazda glc custom l   2.70
# 377   japan                   mazda glc custom   3.23
# 378     usa             plymouth horizon miser   2.63
# 379     usa                     mercury lynx l   2.78
# 380   japan                   nissan stanza xe   2.78
# 381   japan                       honda accord   2.78
# 382   japan                     toyota corolla   2.94
# 383   japan                        honda civic   2.63
# 384   japan                 honda civic (auto)   3.12
# 385   japan                      datsun 310 gx   2.63
# 386     usa              buick century limited   4.00
# 387     usa  oldsmobile cutlass ciera (diesel)   2.63
# 388     usa         chrysler lebaron medallion   3.85
# 389     usa                     ford granada l   4.55
# 390   japan                   toyota celica gt   3.12
# 391     usa                  dodge charger 2.2   2.78
# 392     usa                   chevrolet camaro   3.70
# 393     usa                    ford mustang gl   3.70
# 394  europe                          vw pickup   2.27
# 395     usa                      dodge rampage   3.12
# 396     usa                        ford ranger   3.57
# 397     usa                     chevrolet s-10   3.23
#
# [392 rows x 9 columns]

# %% [markdown]
# 148. __Add__ a new column __"gpm"__ with fuel efficiency in gallons per 100 miles unit. __Drop__ the mpg column!

# %% [markdown]
# 149. __Create__ the following plot! Is there a __significant__ (linear) __relationship__ between horsepower and gpm?

# %%
sns.jointplot(data=cars,y='gpm',x='horsepower',kind='reg')
# Out:
# C:\Users\Harshraj\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 150. Also create the following plot!

# %%
sns.lmplot(data=cars,y='gpm',x='horsepower',col='origin')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 151. __Create__ the following __heatmap__ (correlation matrix)!

# %%
sns.heatmap(data=cars.corr(),annot=True,cmap='Reds')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 152. __Drop__ the columns __displacement__ and __acceleration__ and create the following __pairplot__ (sns.pairplot) for cars (kind = scatter)!

# %%
cars.drop(columns=['displacement','acceleration'],inplace=True)

# %%
sns.pairplot(data=cars,kind='scatter')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 153. __Run__ the cell and __inspect__!

# %%
# run!
sns.set(font_scale=1.5)
sns.pairplot(data = cars[["gpm", "horsepower", "origin"]], kind = "scatter", hue = "origin", aspect =2, height = 3)
plt.show()
# Out:
# C:\Users\Harshraj\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# -----------------

# %% [markdown]
# ## Option 2: Guided and Instructed

# %% [markdown]
# ### No further guidance this time! Prepare yourself for the final challenge! (Take a look at the Hints, if necessary)

# %% [markdown]
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# # Hints (Spoiler!)

# %% [markdown]
# 142. cars.dropna(inplace= True)

# %% [markdown]
# 143.

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.5, palette="viridis")
sns.countplot(data = cars, hue = "origin", x = "model_year")
plt.show()

# %% [markdown]
# 144.

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.5, palette="viridis")
sns.violinplot(data = cars, x = "origin", y = "mpg", dodge = True)
sns.swarmplot(data = cars, x = "origin", y = "mpg", dodge = True, color = "black")
plt.show()

# %% [markdown]
# 145.

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.5)
sns.barplot(data = cars, x = "origin", y = "mpg", dodge = True)
plt.show()

# %% [markdown]
# 146.

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.5)
sns.pointplot(data = cars, x = "model_year", y = "mpg", hue = "origin", dodge = True, ci = 95)
plt.show()

# %% [markdown]
# 147. pass horsepower, weight & displacement to y!

# %% [markdown]
# 148. 1 / mpg * 100

# %% [markdown]
# 149.

# %%
sns.set(font_scale=1.5)
sns.jointplot(data = cars, x = "horsepower", y = "gpm", height = 8, kind = "reg")
plt.show()

# %% [markdown]
# 150.

# %%
sns.set(font_scale=1.5)
sns.lmplot(data = cars, x = "weight", y = "horsepower", col = "origin")
plt.show()

# %% [markdown]
# 151.

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(cars.corr(), annot= True, cmap = "Reds")
plt.show()

# %% [markdown]
# 152.

# %%
sns.set(font_scale=1.5)
sns.pairplot(data = cars, kind = "scatter")
plt.show()

# %% [markdown]
# 153. Nothing to do!
