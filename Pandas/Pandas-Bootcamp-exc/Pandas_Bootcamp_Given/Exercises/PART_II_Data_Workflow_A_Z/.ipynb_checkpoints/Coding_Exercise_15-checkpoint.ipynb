# %% [markdown]
# # Coding Exercises (Part 12)

# %% [markdown]
# ## Complete Data Workflow A-Z: Data Preparation and Feature Creation

# %% [markdown]
# ### Exercise 15: Data Preparation and Feature Creation

# %% [markdown]
# Now, you will have the opportunity to analyze your own dataset. <br>
# __Follow the instructions__ and insert your code! You are either requested to
# - Complete the Code and __Fill in the gaps__. Gaps are marked with "__---__" and are __placeholders__ for your code fragment.
# - Write Code completely __on your own__

# %% [markdown]
# In some exercises, you will find questions that can only be answered, if your code is correct and returns the right output! The correct answer is provided below your coding cell. There you can check whether your code is correct.

# %% [markdown]
# If you need a hint, check the __Hints Section__ at the end of this Notebook. Exercises and Hints are numerated accordingly.

# %% [markdown]
# If you need some further help or if you want to check your code, you can also check the __solutions notebook__.

# %% [markdown]
# ### Have Fun!

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Option 1: Self_guided

# %% [markdown]
# 132. Import and inspect the cars dataset (cars.csv)!

# %% [markdown]
# 133. __Transform__ the format in the model_year column to __full year format__ (e.g. 1970 instead of 70)!

# %% [markdown]
# 134. __Transform__ the __mpg__ column in way that the ralationship with the horsepower feature is __linear__/closer to linear!<br> __Visualize__ before and after!<br> <br>
# (Hint: Gallons per 100 miles might be a good format)

# %% [markdown]
# 135. Create a __new column__ with the __manufacturer__ name!

# %% [markdown]
# 136. Add a __new column__ with the respective __continent__ (north america, asia, europe)!

# %% [markdown]
# 137. __Visualize__ and inspect whether there are any __extreme values__ / outliers in the __numerical columns__ that are worth to be __capped__ / __floored__!

# %% [markdown]
# 138. __Bin / discretize__ the __weight__ column! The __25%__ of cars with the __lowest weight__ shall get the label __"light"__, the __25%__ of cars with the __highest weight__ shall get the label __"heavy"__ and the remaining __50%__ the label __"medium"__! Create a new column __"weight_cat"__!

# %% [markdown]
# 139. __Drop__ the columns "cylinders", "displacement", "weight", "acceleration", "name", "mpg"!

# %% [markdown]
# 140. Bring the columns __horsepower__ and the column that you created in __question 133__ (transformed mpg column) to the same __scale__ by calculating __z-scores__! __Visualize__ before and after!

# %% [markdown]
# 141. __Transform__ the columns __model_year__ and __origin__ into (k-1) columns with __dummy variables__!

# %% [markdown]
# -----------------------------------------------------------------------------

# %% [markdown]
# ## Option 2: Guided and Instructed

# %% [markdown]
# ### No further guidance this time! Prepare yourself for the final challenge! (Take a look at the Hints, if necessary)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
cars= pd.read_csv('cars.csv')

# %%
cars.model_year= cars.model_year.add(1900)

# %%
cars.plot(kind='scatter',x='horsepower',y ='mpg',
          figsize=(12,8),fontsize=15)#scatter requires x and y.

# %%
cars['gpm']= (1/cars.mpg*100).round(2)
cars
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# 5    15.0          8         429.0       198.0    4341          10.0
# 6    14.0          8         454.0       220.0    4354           9.0
# 7    14.0          8         440.0       215.0    4312           8.5
# 8    14.0          8         455.0       225.0    4425          10.0
# 9    15.0          8         390.0       190.0    3850           8.5
# 10   15.0          8         383.0       170.0    3563          10.0
# 11   14.0          8         340.0       160.0    3609           8.0
# 12   15.0          8         400.0       150.0    3761           9.5
# 13   14.0          8         455.0       225.0    3086          10.0
# 14   24.0          4         113.0        95.0    2372          15.0
# 15   22.0          6         198.0        95.0    2833          15.5
# 16   18.0          6         199.0        97.0    2774          15.5
# 17   21.0          6         200.0        85.0    2587          16.0
# 18   27.0          4          97.0        88.0    2130          14.5
# 19   26.0          4          97.0        46.0    1835          20.5
# 20   25.0          4         110.0        87.0    2672          17.5
# 21   24.0          4         107.0        90.0    2430          14.5
# 22   25.0          4         104.0        95.0    2375          17.5
# 23   26.0          4         121.0       113.0    2234          12.5
# 24   21.0          6         199.0        90.0    2648          15.0
# 25   10.0          8         360.0       215.0    4615          14.0
# 26   10.0          8         307.0       200.0    4376          15.0
# 27   11.0          8         318.0       210.0    4382          13.5
# 28    9.0          8         304.0       193.0    4732          18.5
# 29   27.0          4          97.0        88.0    2130          14.5
# ..    ...        ...           ...         ...     ...           ...
# 368  27.0          4         112.0        88.0    2640          18.6
# 369  34.0          4         112.0        88.0    2395          18.0
# 370  31.0          4         112.0        85.0    2575          16.2
# 371  29.0          4         135.0        84.0    2525          16.0
# 372  27.0          4         151.0        90.0    2735          18.0
# 373  24.0          4         140.0        92.0    2865          16.4
# 374  23.0          4         151.0         NaN    3035          20.5
# 375  36.0          4         105.0        74.0    1980          15.3
# 376  37.0          4          91.0        68.0    2025          18.2
# 377  31.0          4          91.0        68.0    1970          17.6
# 378  38.0          4         105.0        63.0    2125          14.7
# 379  36.0          4          98.0        70.0    2125          17.3
# 380  36.0          4         120.0        88.0    2160          14.5
# 381  36.0          4         107.0        75.0    2205          14.5
# 382  34.0          4         108.0        70.0    2245          16.9
# 383  38.0          4          91.0        67.0    1965          15.0
# 384  32.0          4          91.0        67.0    1965          15.7
# 385  38.0          4          91.0        67.0    1995          16.2
# 386  25.0          6         181.0       110.0    2945          16.4
# 387  38.0          6         262.0        85.0    3015          17.0
# 388  26.0          4         156.0        92.0    2585          14.5
# 389  22.0          6         232.0       112.0    2835          14.7
# 390  32.0          4         144.0        96.0    2665          13.9
# 391  36.0          4         135.0        84.0    2370          13.0
# 392  27.0          4         151.0        90.0    2950          17.3
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                               name    gpm
# 0            70     usa          chevrolet chevelle malibu   5.56
# 1            70     usa                  buick skylark 320   6.67
# 2            70     usa                 plymouth satellite   5.56
# 3            70     usa                      amc rebel sst   6.25
# 4            70     usa                        ford torino   5.88
# 5            70     usa                   ford galaxie 500   6.67
# 6            70     usa                   chevrolet impala   7.14
# 7            70     usa                  plymouth fury iii   7.14
# 8            70     usa                   pontiac catalina   7.14
# 9            70     usa                 amc ambassador dpl   6.67
# 10           70     usa                dodge challenger se   6.67
# 11           70     usa                 plymouth 'cuda 340   7.14
# 12           70     usa              chevrolet monte carlo   6.67
# 13           70     usa            buick estate wagon (sw)   7.14
# 14           70   japan              toyota corona mark ii   4.17
# 15           70     usa                    plymouth duster   4.55
# 16           70     usa                         amc hornet   5.56
# 17           70     usa                      ford maverick   4.76
# 18           70   japan                       datsun pl510   3.70
# 19           70  europe               vw 1131 deluxe sedan   3.85
# 20           70  europe                        peugeot 504   4.00
# 21           70  europe                        audi 100 ls   4.17
# 22           70  europe                           saab 99e   4.00
# 23           70  europe                           bmw 2002   3.85
# 24           70     usa                        amc gremlin   4.76
# 25           70     usa                          ford f250  10.00
# 26           70     usa                      chevrolet c20  10.00
# 27           70     usa                         dodge d200   9.09
# 28           70     usa                           ih 1200d  11.11
# 29           71   japan                       datsun pl510   3.70
# ..          ...     ...                                ...    ...
# 376  37.0          4          91.0        68.0    2025          18.2
# 377  31.0          4          91.0        68.0    1970          17.6
# 378  38.0          4         105.0        63.0    2125          14.7
# 379  36.0          4          98.0        70.0    2125          17.3
# 380  36.0          4         120.0        88.0    2160          14.5
# 381  36.0          4         107.0        75.0    2205          14.5
# 382  34.0          4         108.0        70.0    2245          16.9
# 383  38.0          4          91.0        67.0    1965          15.0
# 384  32.0          4          91.0        67.0    1965          15.7
# 385  38.0          4          91.0        67.0    1995          16.2
# 386  25.0          6         181.0       110.0    2945          16.4
# 387  38.0          6         262.0        85.0    3015          17.0
# 388  26.0          4         156.0        92.0    2585          14.5
# 389  22.0          6         232.0       112.0    2835          14.7
# 390  32.0          4         144.0        96.0    2665          13.9
# 391  36.0          4         135.0        84.0    2370          13.0
# 392  27.0          4         151.0        90.0    2950          17.3
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                               name    gpm manufacturer
# 0            70     usa          chevrolet chevelle malibu   5.56    chevrolet
# 1            70     usa                  buick skylark 320   6.67        buick
# 2            70     usa                 plymouth satellite   5.56     plymouth
# 3            70     usa                      amc rebel sst   6.25          amc
# 4            70     usa                        ford torino   5.88         ford
# 5            70     usa                   ford galaxie 500   6.67         ford
# 6            70     usa                   chevrolet impala   7.14    chevrolet
# 7            70     usa                  plymouth fury iii   7.14     plymouth
# 8            70     usa                   pontiac catalina   7.14      pontiac
# 9            70     usa                 amc ambassador dpl   6.67          amc
# 10           70     usa                dodge challenger se   6.67        dodge
# 11           70     usa                 plymouth 'cuda 340   7.14     plymouth
# 12           70     usa              chevrolet monte carlo   6.67    chevrolet
# 13           70     usa            buick estate wagon (sw)   7.14        buick
# 14           70   japan              toyota corona mark ii   4.17       toyota
# 15           70     usa                    plymouth duster   4.55     plymouth
# 16           70     usa                         amc hornet   5.56          amc
# 17           70     usa                      ford maverick   4.76         ford
# 18           70   japan                       datsun pl510   3.70       datsun
# 19           70  europe               vw 1131 deluxe sedan   3.85           vw
# 20           70  europe                        peugeot 504   4.00      peugeot
# 21           70  europe                        audi 100 ls   4.17         audi
# 22           70  europe                           saab 99e   4.00         saab
# 23           70  europe                           bmw 2002   3.85          bmw
# 24           70     usa                        amc gremlin   4.76          amc
# 25           70     usa                          ford f250  10.00         ford
# 26           70     usa                      chevrolet c20  10.00    chevrolet
# 27           70     usa                         dodge d200   9.09        dodge
# 28           70     usa                           ih 1200d  11.11           ih
# 29           71   japan                       datsun pl510   3.70       datsun
# ..          ...     ...                                ...    ...          ...
# 368          82     usa           chevrolet cavalier wagon   3.70    chevrolet
# 369          82     usa          chevrolet cavalier 2-door   2.94    chevrolet
# 370          82     usa         pontiac j2000 se hatchback   3.23      pontiac
# 371          82     usa                     dodge aries se   3.45        dodge
# 372          82     usa                    pontiac phoenix   3.70      pontiac
# 373          82     usa               ford fairmont futura   4.17         ford
# 374          82     usa                     amc concord dl   4.35          amc
# 375          82  europe                        vw rabbit l   2.78           vw
# 376          82   japan                 mazda glc custom l   2.70        mazda
# 377          82   japan                   mazda glc custom   3.23        mazda
# 378          82     usa             plymouth horizon miser   2.63     plymouth
# 379          82     usa                     mercury lynx l   2.78      mercury
# 380          82   japan                   nissan stanza xe   2.78       nissan
# 381          82   japan                       honda accord   2.78        honda
# 382          82   japan                     toyota corolla   2.94       toyota
# 383          82   japan                        honda civic   2.63        honda
# 384          82   japan                 honda civic (auto)   3.12        honda
# 385          82   japan                      datsun 310 gx   2.63       datsun
# 386          82     usa              buick century limited   4.00        buick
# 387          82     usa  oldsmobile cutlass ciera (diesel)   2.63   oldsmobile
# 388          82     usa         chrysler lebaron medallion   3.85     chrysler
# 389          82     usa                     ford granada l   4.55         ford
# 390          82   japan                   toyota celica gt   3.12       toyota
# 391          82     usa                  dodge charger 2.2   2.78        dodge
# 392          82     usa                   chevrolet camaro   3.70    chevrolet
# 393          82     usa                    ford mustang gl   3.70         ford
# 394          82  europe                          vw pickup   2.27           vw
# 395          82     usa                      dodge rampage   3.12        dodge
# 396          82     usa                        ford ranger   3.57         ford
# 397          82     usa                     chevrolet s-10   3.23    chevrolet
#
# [398 rows x 11 columns]

# %%
cars['continent']= cars.origin.map({'usa':'north america','europe':'europe','japan':'asia'})

# %%
cars.plot(figsize=(20,15),subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000017678DDAE10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000017678EE1D68>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000017679125E80>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000017678BB4F98>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000176792BE0F0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001767903C208>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001767907C320>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001767928E470>],
#       dtype=object)

# %%
cars['weight_category'] = pd.qcut(cars.weight,[0,.25,.75,1],precision=2,
                                  labels=['light','medium','heavy'])
cars.weight_category.value_counts()
# Out:
# medium    198
# heavy     100
# light     100
# Name: weight_category, dtype: int64

# %%
cars.drop(['cylinders','displacement','weight','acceleration','name','mpg'],axis=1,inplace=True)

# %%
cars.loc[:,['horsepower','gpm']].plot()

# %%
cars['horsepower_z']= round((cars.horsepower - cars.horsepower.mean())/cars.horsepower.std(),2)

# %%
cars['gpm']=round((cars.gpm-cars.gpm.mean())/cars.gpm.std(),2)

# %%
cars.loc[:,['horsepower_z','gpm']].plot()

# %%
cars=pd.get_dummies(cars,drop_first=True,columns=['model_year','origin'])

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 20 columns):
# horsepower         392 non-null float64
# gpm                398 non-null float64
# manufacturer       398 non-null object
# continent          398 non-null object
# weight_category    398 non-null category
# horsepower_z       392 non-null float64
# model_year_1971    398 non-null uint8
# model_year_1972    398 non-null uint8
# model_year_1973    398 non-null uint8
# model_year_1974    398 non-null uint8
# model_year_1975    398 non-null uint8
# model_year_1976    398 non-null uint8
# model_year_1977    398 non-null uint8
# model_year_1978    398 non-null uint8
# model_year_1979    398 non-null uint8
# model_year_1980    398 non-null uint8
# model_year_1981    398 non-null uint8
# model_year_1982    398 non-null uint8
# origin_japan       398 non-null uint8
# origin_usa         398 non-null uint8
# dtypes: category(1), float64(3), object(2), uint8(14)
# memory usage: 21.6+ KB

# %% [markdown]
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ----------------------------

# %% [markdown]
# ## Hints (Spoiler!)

# %% [markdown]
# 132. At this point, you should know this!

# %% [markdown]
# 133. Use the add() method.

# %% [markdown]
# 134. 1/mpg * 100

# %% [markdown]
# 135. string method split()

# %% [markdown]
# 136. Pass a mapper/dictionary to the map() method

# %% [markdown]
# 137. Lineplot for all columns. Hint: Nothing to cap / floor

# %% [markdown]
# 138. pd.qcut()

# %% [markdown]
# 139. drop() method

# %% [markdown]
# 140. z-score for all elements in horsepower column: z-score = (cars.horsepower - cars.horsepower.mean()) / cars.horsepower.std()

# %% [markdown]
# 141. pd.get_dummies(); drop_first = True
